# %%
import os
import glob
import copy
from pathlib import Path
import pandas as pd
import numpy as np
import matplotlib.dates as mdates
import matplotlib.pyplot as plt

# SB3 Imports
from stable_baselines3 import SAC
from stable_baselines3.common.callbacks import CheckpointCallback
from stable_baselines3.common.vec_env import SubprocVecEnv
from stable_baselines3.common.monitor import Monitor

# CityLearn Imports
from citylearn.citylearn import CityLearnEnv
from citylearn.wrappers import NormalizedObservationWrapper, StableBaselines3Wrapper

# %% [markdown]
# # Train

# %%
def make_env(schema_dict, episode_time_steps):
    """
    Factory function for SubprocVecEnv to instantiate separate environments.
    Rendering and logging parameters are removed to maximize simulation speed.
    """

    def _init():
        env = CityLearnEnv(
            schema=schema_dict, central_agent=True, episode_time_steps=episode_time_steps
        )
        env = NormalizedObservationWrapper(env)
        env = StableBaselines3Wrapper(env)
        env = Monitor(env)
        return env

    return _init

# %%
# ------------------------------------------------------------------
# 0. Global Parameters
# ------------------------------------------------------------------
num_houses = 6
num_cpu = 2  # Set this to the number of physical cores available
episode_length = 168

print(f"\n{'='*60}")
print(f"INITIALIZING VECTORIZED EXPERIMENT: {num_houses} HOUSE(S) | {num_cpu} WORKERS")
print(f"{'='*60}\n")

# ------------------------------------------------------------------
# 1. Configuration & Paths
# ------------------------------------------------------------------
base_schema = "citylearn_challenge_2023_phase_3_1"
session_name = f"{num_houses}_house_sac_vectorized_new_reward"

tensorboard_log_dir = Path.cwd() / "training_logs"
model_dir = Path.cwd() / "models" / session_name
kpi_dir = Path.cwd() / "kpi"
os.makedirs(model_dir, exist_ok=True)
os.makedirs(kpi_dir, exist_ok=True)
os.makedirs(tensorboard_log_dir, exist_ok=True)

# ------------------------------------------------------------------
# 2. Dynamic Schema Extraction
# ------------------------------------------------------------------
temp_env = CityLearnEnv(schema=base_schema)
schema_dict = copy.deepcopy(temp_env.schema)
building_names = list(schema_dict["buildings"].keys())

if num_houses < len(building_names):
    target_buildings = building_names[:num_houses]
    schema_dict["buildings"] = {b: schema_dict["buildings"][b] for b in target_buildings}

schema_dict["reward_function"]["type"] = "citylearn.reward_function.SolarPenaltyAndComfortReward"
# schema_dict["reward_function"]["attributes"]["coefficients"] = (0.1, 1.0)

# ------------------------------------------------------------------
# 3. Environment Vectorization
# ------------------------------------------------------------------
env_fns = [make_env(schema_dict, episode_length) for _ in range(num_cpu)]
env = SubprocVecEnv(env_fns)

# ------------------------------------------------------------------
# 4. Hyperparameter Scaling & Optimization
# ------------------------------------------------------------------
if num_houses == 1:
    net_arch = [256, 256]
    batch_size = 256
elif num_houses == 3:
    net_arch = [256, 256]
    batch_size = 256
else:
    net_arch = [256, 256, 128]
    batch_size = 512

# ------------------------------------------------------------------
# 5. Checkpoint Callback Setup
# ------------------------------------------------------------------
save_freq_episodes = 200
# Adjust save frequency for parallel environments
save_freq_steps = max((episode_length * save_freq_episodes) // num_cpu, 1)

checkpoint_callback = CheckpointCallback(
    save_freq=save_freq_steps,
    save_path=model_dir,
    name_prefix="sac_model",
    save_replay_buffer=True,
    save_vecnormalize=True,
)
# Out:
# ============================================================
# INITIALIZING VECTORIZED EXPERIMENT: 6 HOUSE(S) | 2 WORKERS
# ============================================================
# INFO:root:Go here /home/ntpt/.cache/citylearn/v2.5.0/datasets/citylearn_challenge_2023_phase_3_1/schema.json

# %%
# ------------------------------------------------------------------
# 6. Model Initialization or Resumption
# ------------------------------------------------------------------
import torch
import contextlib


@contextlib.contextmanager
def patch_module_load_state_dict():
    """
    Context manager to intercept PyTorch's state_dict loading.
    Strips the `_orig_mod.` prefix generated by torch.compile()
    so compiled checkpoints can map to uncompiled architectures natively.
    """
    original_load = torch.nn.Module.load_state_dict

    def patched_load(self, state_dict, *args, **kwargs):
        clean_dict = {k.replace("_orig_mod.", ""): v for k, v in state_dict.items()}
        return original_load(self, clean_dict, *args, **kwargs)

    try:
        torch.nn.Module.load_state_dict = patched_load
        yield
    finally:
        torch.nn.Module.load_state_dict = original_load


list_of_files = glob.glob(f"{model_dir}/*.zip")
latest_model_path = max(list_of_files, key=os.path.getctime) if list_of_files else None

if latest_model_path:
    print(f"Resuming {num_houses}-house training from checkpoint: {latest_model_path}")

    # 1. Load natively while intercepting and cleaning the state_dict
    with patch_module_load_state_dict():
        model = SAC.load(latest_model_path, env=env, tensorboard_log=tensorboard_log_dir)

    # 2. Re-apply torch.compile for the resumed training session
    model.policy.actor = torch.compile(model.policy.actor)
    model.policy.critic = torch.compile(model.policy.critic)

    # 3. Restore the replay buffer
    replay_buffer_path = latest_model_path.replace(".zip", "_replay_buffer.pkl")
    if os.path.exists(replay_buffer_path):
        model.load_replay_buffer(replay_buffer_path)
        print("Replay buffer loaded successfully.")

    reset_steps = False
else:
    print(f"Initializing new {num_houses}-house vectorized model...")
    model = SAC(
        "MlpPolicy",
        env,
        policy_kwargs=dict(net_arch=net_arch),
        batch_size=batch_size,
        buffer_size=100000,
        verbose=1,
        tensorboard_log=tensorboard_log_dir,
    )

    model.policy.actor = torch.compile(model.policy.actor)
    model.policy.critic = torch.compile(model.policy.critic)

    reset_steps = True
# Out:
# Resuming 6-house training from checkpoint: /home/ntpt/Documents/Uni/Big_Data/GroupWork/FRL_Smart_Grid/baseline/models/6_house_sac_vectorized_new_reward/6_house_sac_vectorized_new_reward_final.zip
# Replay buffer loaded successfully.

# %%
# ------------------------------------------------------------------
# 7. Execution
# ------------------------------------------------------------------
total_timesteps = 750_000

print(f"Target Timesteps: {total_timesteps}")
model.learn(
    total_timesteps=total_timesteps,
    callback=checkpoint_callback,
    tb_log_name=session_name,
    reset_num_timesteps=reset_steps,
    log_interval=1,  # Forces logging after every episode completion
)
# Out:
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 167       |
# |    ep_rew_mean     | -8.32e+03 |
# | time/              |           |
# |    episodes        | 2525      |
# |    fps             | 22        |
# |    time_elapsed    | 6681      |
# |    total_timesteps | 422106    |
# | train/             |           |
# |    actor_loss      | 3.26e+03  |
# |    critic_loss     | 413       |
# |    ent_coef        | 0.625     |
# |    ent_coef_loss   | -0.0916   |
# |    learning_rate   | 0.0003    |
# |    n_updates       | 211000    |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 167       |
# |    ep_rew_mean     | -8.32e+03 |
# | time/              |           |
# |    episodes        | 2526      |
# |    fps             | 22        |
# |    time_elapsed    | 6681      |
# |    total_timesteps | 422106    |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 167       |
# |    ep_rew_mean     | -8.32e+03 |
# | time/              |           |
# |    episodes        | 2527      |
# |    fps             | 22        |
# |    time_elapsed    | 6702      |
# |    total_timesteps | 422440    |
# | train/             |           |
# |    actor_loss      | 3.15e+03  |
# |    critic_loss     | 421       |
# |    ent_coef        | 0.62      |
# |    ent_coef_loss   | -0.113    |
# |    learning_rate   | 0.0003    |
# |    n_updates       | 211167    |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 167       |
# |    ep_rew_mean     | -8.32e+03 |
# | time/              |           |
# |    episodes        | 2528      |
# |    fps             | 22        |
# |    time_elapsed    | 6702      |
# |    total_timesteps | 422440    |
# ----------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 167      |
# |    ep_rew_mean     | -8.3e+03 |
# | time/              |          |
# |    episodes        | 2529     |
# |    fps             | 22       |
# |    time_elapsed    | 6727     |
# |    total_timesteps | 422774   |
# | train/             |          |
# |    actor_loss      | 3.34e+03 |
# |    critic_loss     | 395      |
# |    ent_coef        | 0.612    |
# |    ent_coef_loss   | -0.066   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 211334   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 167      |
# |    ep_rew_mean     | -8.3e+03 |
# | time/              |          |
# |    episodes        | 2530     |
# |    fps             | 22       |
# |    time_elapsed    | 6727     |
# |    total_timesteps | 422774   |
# ---------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 167       |
# |    ep_rew_mean     | -8.25e+03 |
# | time/              |           |
# |    episodes        | 2531      |
# |    fps             | 22        |
# |    time_elapsed    | 6748      |
# |    total_timesteps | 423108    |
# | train/             |           |
# |    actor_loss      | 3.3e+03   |
# |    critic_loss     | 331       |
# |    ent_coef        | 0.617     |
# |    ent_coef_loss   | -0.178    |
# |    learning_rate   | 0.0003    |
# |    n_updates       | 211501    |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 167       |
# |    ep_rew_mean     | -8.25e+03 |
# | time/              |           |
# |    episodes        | 2532      |
# |    fps             | 22        |
# |    time_elapsed    | 6748      |
# |    total_timesteps | 423108    |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 167       |
# |    ep_rew_mean     | -8.25e+03 |
# | time/              |           |
# |    episodes        | 2533      |
# |    fps             | 22        |
# |    time_elapsed    | 6771      |
# |    total_timesteps | 423442    |
# | train/             |           |
# |    actor_loss      | 3.26e+03  |
# |    critic_loss     | 407       |
# |    ent_coef        | 0.608     |
# |    ent_coef_loss   | -0.0761   |
# |    learning_rate   | 0.0003    |
# |    n_updates       | 211668    |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 167       |
# |    ep_rew_mean     | -8.25e+03 |
# | time/              |           |
# |    episodes        | 2534      |
# |    fps             | 22        |
# |    time_elapsed    | 6771      |
# |    total_timesteps | 423442    |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 167       |
# |    ep_rew_mean     | -8.27e+03 |
# | time/              |           |
# |    episodes        | 2535      |
# |    fps             | 22        |
# |    time_elapsed    | 6788      |
# |    total_timesteps | 423776    |
# | train/             |           |
# |    actor_loss      | 3.36e+03  |
# |    critic_loss     | 400       |
# |    ent_coef        | 0.621     |
# |    ent_coef_loss   | 0.14      |
# |    learning_rate   | 0.0003    |
# |    n_updates       | 211835    |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 167       |
# |    ep_rew_mean     | -8.27e+03 |
# | time/              |           |
# |    episodes        | 2536      |
# |    fps             | 22        |
# |    time_elapsed    | 6788      |
# |    total_timesteps | 423776    |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 167       |
# |    ep_rew_mean     | -8.25e+03 |
# | time/              |           |
# |    episodes        | 2537      |
# |    fps             | 22        |
# |    time_elapsed    | 6804      |
# |    total_timesteps | 424110    |
# | train/             |           |
# |    actor_loss      | 3.41e+03  |
# |    critic_loss     | 336       |
# |    ent_coef        | 0.624     |
# |    ent_coef_loss   | -0.0167   |
# |    learning_rate   | 0.0003    |
# |    n_updates       | 212002    |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 167       |
# |    ep_rew_mean     | -8.25e+03 |
# | time/              |           |
# |    episodes        | 2538      |
# |    fps             | 22        |
# |    time_elapsed    | 6804      |
# |    total_timesteps | 424110    |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 167       |
# |    ep_rew_mean     | -8.23e+03 |
# | time/              |           |
# |    episodes        | 2539      |
# |    fps             | 22        |
# |    time_elapsed    | 6821      |
# |    total_timesteps | 424444    |
# | train/             |           |
# |    actor_loss      | 3.36e+03  |
# |    critic_loss     | 574       |
# |    ent_coef        | 0.61      |
# |    ent_coef_loss   | -0.0546   |
# |    learning_rate   | 0.0003    |
# |    n_updates       | 212169    |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 167       |
# |    ep_rew_mean     | -8.23e+03 |
# | time/              |           |
# |    episodes        | 2540      |
# |    fps             | 22        |
# |    time_elapsed    | 6821      |
# |    total_timesteps | 424444    |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 167       |
# |    ep_rew_mean     | -8.27e+03 |
# | time/              |           |
# |    episodes        | 2541      |
# |    fps             | 22        |
# |    time_elapsed    | 6838      |
# |    total_timesteps | 424778    |
# | train/             |           |
# |    actor_loss      | 3.19e+03  |
# |    critic_loss     | 1.11e+03  |
# |    ent_coef        | 0.612     |
# |    ent_coef_loss   | -0.0913   |
# |    learning_rate   | 0.0003    |
# |    n_updates       | 212336    |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 167       |
# |    ep_rew_mean     | -8.27e+03 |
# | time/              |           |
# |    episodes        | 2542      |
# |    fps             | 22        |
# |    time_elapsed    | 6838      |
# |    total_timesteps | 424778    |
# ----------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 167      |
# |    ep_rew_mean     | -8.3e+03 |
# | time/              |          |
# |    episodes        | 2543     |
# |    fps             | 22       |
# |    time_elapsed    | 6854     |
# |    total_timesteps | 425112   |
# | train/             |          |
# |    actor_loss      | 3.3e+03  |
# |    critic_loss     | 326      |
# |    ent_coef        | 0.619    |
# |    ent_coef_loss   | -0.0436  |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 212503   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 167      |
# |    ep_rew_mean     | -8.3e+03 |
# | time/              |          |
# |    episodes        | 2544     |
# |    fps             | 22       |
# |    time_elapsed    | 6854     |
# |    total_timesteps | 425112   |
# ---------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 167       |
# |    ep_rew_mean     | -8.24e+03 |
# | time/              |           |
# |    episodes        | 2545      |
# |    fps             | 22        |
# |    time_elapsed    | 6870      |
# |    total_timesteps | 425446    |
# | train/             |           |
# |    actor_loss      | 3.16e+03  |
# |    critic_loss     | 403       |
# |    ent_coef        | 0.615     |
# |    ent_coef_loss   | -0.447    |
# |    learning_rate   | 0.0003    |
# |    n_updates       | 212670    |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 167       |
# |    ep_rew_mean     | -8.24e+03 |
# | time/              |           |
# |    episodes        | 2546      |
# |    fps             | 22        |
# |    time_elapsed    | 6870      |
# |    total_timesteps | 425446    |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 167       |
# |    ep_rew_mean     | -8.23e+03 |
# | time/              |           |
# |    episodes        | 2547      |
# |    fps             | 22        |
# |    time_elapsed    | 6887      |
# |    total_timesteps | 425780    |
# | train/             |           |
# |    actor_loss      | 3.17e+03  |
# |    critic_loss     | 610       |
# |    ent_coef        | 0.592     |
# |    ent_coef_loss   | -0.0187   |
# |    learning_rate   | 0.0003    |
# |    n_updates       | 212837    |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 167       |
# |    ep_rew_mean     | -8.23e+03 |
# | time/              |           |
# |    episodes        | 2548      |
# |    fps             | 22        |
# |    time_elapsed    | 6887      |
# |    total_timesteps | 425780    |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 167       |
# |    ep_rew_mean     | -8.24e+03 |
# | time/              |           |
# |    episodes        | 2549      |
# |    fps             | 22        |
# |    time_elapsed    | 6903      |
# |    total_timesteps | 426114    |
# | train/             |           |
# |    actor_loss      | 3.23e+03  |
# |    critic_loss     | 308       |
# |    ent_coef        | 0.592     |
# |    ent_coef_loss   | 0.115     |
# |    learning_rate   | 0.0003    |
# |    n_updates       | 213004    |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 167       |
# |    ep_rew_mean     | -8.24e+03 |
# | time/              |           |
# |    episodes        | 2550      |
# |    fps             | 22        |
# |    time_elapsed    | 6903      |
# |    total_timesteps | 426114    |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 167       |
# |    ep_rew_mean     | -8.24e+03 |
# | time/              |           |
# |    episodes        | 2551      |
# |    fps             | 22        |
# |    time_elapsed    | 6918      |
# |    total_timesteps | 426448    |
# | train/             |           |
# |    actor_loss      | 3.21e+03  |
# |    critic_loss     | 350       |
# |    ent_coef        | 0.598     |
# |    ent_coef_loss   | 0.108     |
# |    learning_rate   | 0.0003    |
# |    n_updates       | 213171    |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 167       |
# |    ep_rew_mean     | -8.24e+03 |
# | time/              |           |
# |    episodes        | 2552      |
# |    fps             | 22        |
# |    time_elapsed    | 6918      |
# |    total_timesteps | 426448    |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 167       |
# |    ep_rew_mean     | -8.24e+03 |
# | time/              |           |
# |    episodes        | 2553      |
# |    fps             | 22        |
# |    time_elapsed    | 6934      |
# |    total_timesteps | 426782    |
# | train/             |           |
# |    actor_loss      | 3.21e+03  |
# |    critic_loss     | 361       |
# |    ent_coef        | 0.609     |
# |    ent_coef_loss   | 0.215     |
# |    learning_rate   | 0.0003    |
# |    n_updates       | 213338    |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 167       |
# |    ep_rew_mean     | -8.24e+03 |
# | time/              |           |
# |    episodes        | 2554      |
# |    fps             | 22        |
# |    time_elapsed    | 6934      |
# |    total_timesteps | 426782    |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 167       |
# |    ep_rew_mean     | -8.22e+03 |
# | time/              |           |
# |    episodes        | 2555      |
# |    fps             | 22        |
# |    time_elapsed    | 6951      |
# |    total_timesteps | 427116    |
# | train/             |           |
# |    actor_loss      | 3.32e+03  |
# |    critic_loss     | 609       |
# |    ent_coef        | 0.606     |
# |    ent_coef_loss   | -0.169    |
# |    learning_rate   | 0.0003    |
# |    n_updates       | 213505    |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 167       |
# |    ep_rew_mean     | -8.22e+03 |
# | time/              |           |
# |    episodes        | 2556      |
# |    fps             | 22        |
# |    time_elapsed    | 6951      |
# |    total_timesteps | 427116    |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 167       |
# |    ep_rew_mean     | -8.19e+03 |
# | time/              |           |
# |    episodes        | 2557      |
# |    fps             | 22        |
# |    time_elapsed    | 6967      |
# |    total_timesteps | 427450    |
# | train/             |           |
# |    actor_loss      | 3.29e+03  |
# |    critic_loss     | 355       |
# |    ent_coef        | 0.599     |
# |    ent_coef_loss   | 0.0461    |
# |    learning_rate   | 0.0003    |
# |    n_updates       | 213672    |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 167       |
# |    ep_rew_mean     | -8.19e+03 |
# | time/              |           |
# |    episodes        | 2558      |
# |    fps             | 22        |
# |    time_elapsed    | 6967      |
# |    total_timesteps | 427450    |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 167       |
# |    ep_rew_mean     | -8.17e+03 |
# | time/              |           |
# |    episodes        | 2559      |
# |    fps             | 22        |
# |    time_elapsed    | 6980      |
# |    total_timesteps | 427784    |
# | train/             |           |
# |    actor_loss      | 3.11e+03  |
# |    critic_loss     | 350       |
# |    ent_coef        | 0.595     |
# |    ent_coef_loss   | 0.0385    |
# |    learning_rate   | 0.0003    |
# |    n_updates       | 213839    |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 167       |
# |    ep_rew_mean     | -8.17e+03 |
# | time/              |           |
# |    episodes        | 2560      |
# |    fps             | 22        |
# |    time_elapsed    | 6980      |
# |    total_timesteps | 427784    |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 167       |
# |    ep_rew_mean     | -8.18e+03 |
# | time/              |           |
# |    episodes        | 2561      |
# |    fps             | 22        |
# |    time_elapsed    | 6994      |
# |    total_timesteps | 428118    |
# | train/             |           |
# |    actor_loss      | 3.2e+03   |
# |    critic_loss     | 513       |
# |    ent_coef        | 0.592     |
# |    ent_coef_loss   | 0.231     |
# |    learning_rate   | 0.0003    |
# |    n_updates       | 214006    |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 167       |
# |    ep_rew_mean     | -8.18e+03 |
# | time/              |           |
# |    episodes        | 2562      |
# |    fps             | 22        |
# |    time_elapsed    | 6994      |
# |    total_timesteps | 428118    |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 167       |
# |    ep_rew_mean     | -8.16e+03 |
# | time/              |           |
# |    episodes        | 2563      |
# |    fps             | 22        |
# |    time_elapsed    | 7009      |
# |    total_timesteps | 428452    |
# | train/             |           |
# |    actor_loss      | 3.31e+03  |
# |    critic_loss     | 526       |
# |    ent_coef        | 0.598     |
# |    ent_coef_loss   | -0.0996   |
# |    learning_rate   | 0.0003    |
# |    n_updates       | 214173    |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 167       |
# |    ep_rew_mean     | -8.16e+03 |
# | time/              |           |
# |    episodes        | 2564      |
# |    fps             | 22        |
# |    time_elapsed    | 7009      |
# |    total_timesteps | 428452    |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 167       |
# |    ep_rew_mean     | -8.13e+03 |
# | time/              |           |
# |    episodes        | 2565      |
# |    fps             | 22        |
# |    time_elapsed    | 7025      |
# |    total_timesteps | 428786    |
# | train/             |           |
# |    actor_loss      | 3.19e+03  |
# |    critic_loss     | 378       |
# |    ent_coef        | 0.596     |
# |    ent_coef_loss   | -0.0945   |
# |    learning_rate   | 0.0003    |
# |    n_updates       | 214340    |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 167       |
# |    ep_rew_mean     | -8.13e+03 |
# | time/              |           |
# |    episodes        | 2566      |
# |    fps             | 22        |
# |    time_elapsed    | 7025      |
# |    total_timesteps | 428786    |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 167       |
# |    ep_rew_mean     | -8.19e+03 |
# | time/              |           |
# |    episodes        | 2567      |
# |    fps             | 22        |
# |    time_elapsed    | 7041      |
# |    total_timesteps | 429120    |
# | train/             |           |
# |    actor_loss      | 3.29e+03  |
# |    critic_loss     | 494       |
# |    ent_coef        | 0.597     |
# |    ent_coef_loss   | -0.165    |
# |    learning_rate   | 0.0003    |
# |    n_updates       | 214507    |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 167       |
# |    ep_rew_mean     | -8.19e+03 |
# | time/              |           |
# |    episodes        | 2568      |
# |    fps             | 22        |
# |    time_elapsed    | 7041      |
# |    total_timesteps | 429120    |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 167       |
# |    ep_rew_mean     | -8.21e+03 |
# | time/              |           |
# |    episodes        | 2569      |
# |    fps             | 22        |
# |    time_elapsed    | 7057      |
# |    total_timesteps | 429454    |
# | train/             |           |
# |    actor_loss      | 3.14e+03  |
# |    critic_loss     | 399       |
# |    ent_coef        | 0.604     |
# |    ent_coef_loss   | 0.193     |
# |    learning_rate   | 0.0003    |
# |    n_updates       | 214674    |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 167       |
# |    ep_rew_mean     | -8.21e+03 |
# | time/              |           |
# |    episodes        | 2570      |
# |    fps             | 22        |
# |    time_elapsed    | 7057      |
# |    total_timesteps | 429454    |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 167       |
# |    ep_rew_mean     | -8.16e+03 |
# | time/              |           |
# |    episodes        | 2571      |
# |    fps             | 22        |
# |    time_elapsed    | 7073      |
# |    total_timesteps | 429788    |
# | train/             |           |
# |    actor_loss      | 3.32e+03  |
# |    critic_loss     | 311       |
# |    ent_coef        | 0.603     |
# |    ent_coef_loss   | -0.0354   |
# |    learning_rate   | 0.0003    |
# |    n_updates       | 214841    |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 167       |
# |    ep_rew_mean     | -8.16e+03 |
# | time/              |           |
# |    episodes        | 2572      |
# |    fps             | 22        |
# |    time_elapsed    | 7073      |
# |    total_timesteps | 429788    |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 167       |
# |    ep_rew_mean     | -8.15e+03 |
# | time/              |           |
# |    episodes        | 2573      |
# |    fps             | 22        |
# |    time_elapsed    | 7089      |
# |    total_timesteps | 430122    |
# | train/             |           |
# |    actor_loss      | 3.28e+03  |
# |    critic_loss     | 550       |
# |    ent_coef        | 0.601     |
# |    ent_coef_loss   | 0.181     |
# |    learning_rate   | 0.0003    |
# |    n_updates       | 215008    |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 167       |
# |    ep_rew_mean     | -8.15e+03 |
# | time/              |           |
# |    episodes        | 2574      |
# |    fps             | 22        |
# |    time_elapsed    | 7089      |
# |    total_timesteps | 430122    |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 167       |
# |    ep_rew_mean     | -8.17e+03 |
# | time/              |           |
# |    episodes        | 2575      |
# |    fps             | 22        |
# |    time_elapsed    | 7105      |
# |    total_timesteps | 430456    |
# | train/             |           |
# |    actor_loss      | 3.15e+03  |
# |    critic_loss     | 322       |
# |    ent_coef        | 0.589     |
# |    ent_coef_loss   | -0.165    |
# |    learning_rate   | 0.0003    |
# |    n_updates       | 215175    |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 167       |
# |    ep_rew_mean     | -8.17e+03 |
# | time/              |           |
# |    episodes        | 2576      |
# |    fps             | 22        |
# |    time_elapsed    | 7105      |
# |    total_timesteps | 430456    |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 167       |
# |    ep_rew_mean     | -8.17e+03 |
# | time/              |           |
# |    episodes        | 2577      |
# |    fps             | 22        |
# |    time_elapsed    | 7119      |
# |    total_timesteps | 430790    |
# | train/             |           |
# |    actor_loss      | 3.28e+03  |
# |    critic_loss     | 401       |
# |    ent_coef        | 0.591     |
# |    ent_coef_loss   | -0.246    |
# |    learning_rate   | 0.0003    |
# |    n_updates       | 215342    |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 167       |
# |    ep_rew_mean     | -8.17e+03 |
# | time/              |           |
# |    episodes        | 2578      |
# |    fps             | 22        |
# |    time_elapsed    | 7119      |
# |    total_timesteps | 430790    |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 167       |
# |    ep_rew_mean     | -8.17e+03 |
# | time/              |           |
# |    episodes        | 2579      |
# |    fps             | 22        |
# |    time_elapsed    | 7136      |
# |    total_timesteps | 431124    |
# | train/             |           |
# |    actor_loss      | 3.19e+03  |
# |    critic_loss     | 437       |
# |    ent_coef        | 0.592     |
# |    ent_coef_loss   | -0.0507   |
# |    learning_rate   | 0.0003    |
# |    n_updates       | 215509    |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 167       |
# |    ep_rew_mean     | -8.17e+03 |
# | time/              |           |
# |    episodes        | 2580      |
# |    fps             | 22        |
# |    time_elapsed    | 7136      |
# |    total_timesteps | 431124    |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 167       |
# |    ep_rew_mean     | -8.14e+03 |
# | time/              |           |
# |    episodes        | 2581      |
# |    fps             | 22        |
# |    time_elapsed    | 7150      |
# |    total_timesteps | 431458    |
# | train/             |           |
# |    actor_loss      | 3.2e+03   |
# |    critic_loss     | 470       |
# |    ent_coef        | 0.594     |
# |    ent_coef_loss   | -0.301    |
# |    learning_rate   | 0.0003    |
# |    n_updates       | 215676    |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 167       |
# |    ep_rew_mean     | -8.14e+03 |
# | time/              |           |
# |    episodes        | 2582      |
# |    fps             | 22        |
# |    time_elapsed    | 7150      |
# |    total_timesteps | 431458    |
# ----------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 167      |
# |    ep_rew_mean     | -8.1e+03 |
# | time/              |          |
# |    episodes        | 2583     |
# |    fps             | 22       |
# |    time_elapsed    | 7166     |
# |    total_timesteps | 431792   |
# | train/             |          |
# |    actor_loss      | 3.14e+03 |
# |    critic_loss     | 626      |
# |    ent_coef        | 0.595    |
# |    ent_coef_loss   | 0.13     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 215843   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 167      |
# |    ep_rew_mean     | -8.1e+03 |
# | time/              |          |
# |    episodes        | 2584     |
# |    fps             | 22       |
# |    time_elapsed    | 7166     |
# |    total_timesteps | 431792   |
# ---------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 167       |
# |    ep_rew_mean     | -8.08e+03 |
# | time/              |           |
# |    episodes        | 2585      |
# |    fps             | 22        |
# |    time_elapsed    | 7182      |
# |    total_timesteps | 432126    |
# | train/             |           |
# |    actor_loss      | 3.27e+03  |
# |    critic_loss     | 488       |
# |    ent_coef        | 0.59      |
# |    ent_coef_loss   | -0.321    |
# |    learning_rate   | 0.0003    |
# |    n_updates       | 216010    |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 167       |
# |    ep_rew_mean     | -8.08e+03 |
# | time/              |           |
# |    episodes        | 2586      |
# |    fps             | 22        |
# |    time_elapsed    | 7182      |
# |    total_timesteps | 432126    |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 167       |
# |    ep_rew_mean     | -8.09e+03 |
# | time/              |           |
# |    episodes        | 2587      |
# |    fps             | 22        |
# |    time_elapsed    | 7198      |
# |    total_timesteps | 432460    |
# | train/             |           |
# |    actor_loss      | 3.13e+03  |
# |    critic_loss     | 397       |
# |    ent_coef        | 0.581     |
# |    ent_coef_loss   | 0.254     |
# |    learning_rate   | 0.0003    |
# |    n_updates       | 216177    |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 167       |
# |    ep_rew_mean     | -8.09e+03 |
# | time/              |           |
# |    episodes        | 2588      |
# |    fps             | 22        |
# |    time_elapsed    | 7198      |
# |    total_timesteps | 432460    |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 167       |
# |    ep_rew_mean     | -8.07e+03 |
# | time/              |           |
# |    episodes        | 2589      |
# |    fps             | 22        |
# |    time_elapsed    | 7214      |
# |    total_timesteps | 432794    |
# | train/             |           |
# |    actor_loss      | 3.12e+03  |
# |    critic_loss     | 330       |
# |    ent_coef        | 0.592     |
# |    ent_coef_loss   | 0.138     |
# |    learning_rate   | 0.0003    |
# |    n_updates       | 216344    |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 167       |
# |    ep_rew_mean     | -8.07e+03 |
# | time/              |           |
# |    episodes        | 2590      |
# |    fps             | 22        |
# |    time_elapsed    | 7214      |
# |    total_timesteps | 432794    |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 167       |
# |    ep_rew_mean     | -8.05e+03 |
# | time/              |           |
# |    episodes        | 2591      |
# |    fps             | 22        |
# |    time_elapsed    | 7231      |
# |    total_timesteps | 433128    |
# | train/             |           |
# |    actor_loss      | 3.18e+03  |
# |    critic_loss     | 535       |
# |    ent_coef        | 0.592     |
# |    ent_coef_loss   | -0.119    |
# |    learning_rate   | 0.0003    |
# |    n_updates       | 216511    |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 167       |
# |    ep_rew_mean     | -8.05e+03 |
# | time/              |           |
# |    episodes        | 2592      |
# |    fps             | 22        |
# |    time_elapsed    | 7231      |
# |    total_timesteps | 433128    |
# ----------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 167      |
# |    ep_rew_mean     | -8.1e+03 |
# | time/              |          |
# |    episodes        | 2593     |
# |    fps             | 22       |
# |    time_elapsed    | 7246     |
# |    total_timesteps | 433462   |
# | train/             |          |
# |    actor_loss      | 3.09e+03 |
# |    critic_loss     | 298      |
# |    ent_coef        | 0.589    |
# |    ent_coef_loss   | 0.0423   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 216678   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 167      |
# |    ep_rew_mean     | -8.1e+03 |
# | time/              |          |
# |    episodes        | 2594     |
# |    fps             | 22       |
# |    time_elapsed    | 7246     |
# |    total_timesteps | 433462   |
# ---------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 167       |
# |    ep_rew_mean     | -8.12e+03 |
# | time/              |           |
# |    episodes        | 2595      |
# |    fps             | 22        |
# |    time_elapsed    | 7260      |
# |    total_timesteps | 433796    |
# | train/             |           |
# |    actor_loss      | 3.14e+03  |
# |    critic_loss     | 333       |
# |    ent_coef        | 0.593     |
# |    ent_coef_loss   | 0.203     |
# |    learning_rate   | 0.0003    |
# |    n_updates       | 216845    |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 167       |
# |    ep_rew_mean     | -8.12e+03 |
# | time/              |           |
# |    episodes        | 2596      |
# |    fps             | 22        |
# |    time_elapsed    | 7260      |
# |    total_timesteps | 433796    |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 167       |
# |    ep_rew_mean     | -8.07e+03 |
# | time/              |           |
# |    episodes        | 2597      |
# |    fps             | 22        |
# |    time_elapsed    | 7276      |
# |    total_timesteps | 434130    |
# | train/             |           |
# |    actor_loss      | 3.19e+03  |
# |    critic_loss     | 394       |
# |    ent_coef        | 0.588     |
# |    ent_coef_loss   | -0.37     |
# |    learning_rate   | 0.0003    |
# |    n_updates       | 217012    |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 167       |
# |    ep_rew_mean     | -8.07e+03 |
# | time/              |           |
# |    episodes        | 2598      |
# |    fps             | 22        |
# |    time_elapsed    | 7276      |
# |    total_timesteps | 434130    |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 167       |
# |    ep_rew_mean     | -8.07e+03 |
# | time/              |           |
# |    episodes        | 2599      |
# |    fps             | 22        |
# |    time_elapsed    | 7291      |
# |    total_timesteps | 434464    |
# | train/             |           |
# |    actor_loss      | 3.08e+03  |
# |    critic_loss     | 397       |
# |    ent_coef        | 0.581     |
# |    ent_coef_loss   | -0.196    |
# |    learning_rate   | 0.0003    |
# |    n_updates       | 217179    |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 167       |
# |    ep_rew_mean     | -8.07e+03 |
# | time/              |           |
# |    episodes        | 2600      |
# |    fps             | 22        |
# |    time_elapsed    | 7291      |
# |    total_timesteps | 434464    |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 167       |
# |    ep_rew_mean     | -8.09e+03 |
# | time/              |           |
# |    episodes        | 2601      |
# |    fps             | 22        |
# |    time_elapsed    | 7306      |
# |    total_timesteps | 434798    |
# | train/             |           |
# |    actor_loss      | 3.23e+03  |
# |    critic_loss     | 573       |
# |    ent_coef        | 0.577     |
# |    ent_coef_loss   | -0.0706   |
# |    learning_rate   | 0.0003    |
# |    n_updates       | 217346    |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 167       |
# |    ep_rew_mean     | -8.09e+03 |
# | time/              |           |
# |    episodes        | 2602      |
# |    fps             | 22        |
# |    time_elapsed    | 7306      |
# |    total_timesteps | 434798    |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 167       |
# |    ep_rew_mean     | -8.09e+03 |
# | time/              |           |
# |    episodes        | 2603      |
# |    fps             | 22        |
# |    time_elapsed    | 7321      |
# |    total_timesteps | 435132    |
# | train/             |           |
# |    actor_loss      | 3.21e+03  |
# |    critic_loss     | 325       |
# |    ent_coef        | 0.576     |
# |    ent_coef_loss   | -0.0612   |
# |    learning_rate   | 0.0003    |
# |    n_updates       | 217513    |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 167       |
# |    ep_rew_mean     | -8.09e+03 |
# | time/              |           |
# |    episodes        | 2604      |
# |    fps             | 22        |
# |    time_elapsed    | 7321      |
# |    total_timesteps | 435132    |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 167       |
# |    ep_rew_mean     | -8.08e+03 |
# | time/              |           |
# |    episodes        | 2605      |
# |    fps             | 22        |
# |    time_elapsed    | 7336      |
# |    total_timesteps | 435466    |
# | train/             |           |
# |    actor_loss      | 3.18e+03  |
# |    critic_loss     | 404       |
# |    ent_coef        | 0.575     |
# |    ent_coef_loss   | 0.00178   |
# |    learning_rate   | 0.0003    |
# |    n_updates       | 217680    |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 167       |
# |    ep_rew_mean     | -8.08e+03 |
# | time/              |           |
# |    episodes        | 2606      |
# |    fps             | 22        |
# |    time_elapsed    | 7336      |
# |    total_timesteps | 435466    |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 167       |
# |    ep_rew_mean     | -8.05e+03 |
# | time/              |           |
# |    episodes        | 2607      |
# |    fps             | 22        |
# |    time_elapsed    | 7351      |
# |    total_timesteps | 435800    |
# | train/             |           |
# |    actor_loss      | 3.1e+03   |
# |    critic_loss     | 369       |
# |    ent_coef        | 0.573     |
# |    ent_coef_loss   | -0.126    |
# |    learning_rate   | 0.0003    |
# |    n_updates       | 217847    |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 167       |
# |    ep_rew_mean     | -8.05e+03 |
# | time/              |           |
# |    episodes        | 2608      |
# |    fps             | 22        |
# |    time_elapsed    | 7351      |
# |    total_timesteps | 435800    |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 167       |
# |    ep_rew_mean     | -8.02e+03 |
# | time/              |           |
# |    episodes        | 2609      |
# |    fps             | 22        |
# |    time_elapsed    | 7367      |
# |    total_timesteps | 436134    |
# | train/             |           |
# |    actor_loss      | 2.9e+03   |
# |    critic_loss     | 416       |
# |    ent_coef        | 0.583     |
# |    ent_coef_loss   | -0.0649   |
# |    learning_rate   | 0.0003    |
# |    n_updates       | 218014    |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 167       |
# |    ep_rew_mean     | -8.02e+03 |
# | time/              |           |
# |    episodes        | 2610      |
# |    fps             | 22        |
# |    time_elapsed    | 7367      |
# |    total_timesteps | 436134    |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 167       |
# |    ep_rew_mean     | -8.02e+03 |
# | time/              |           |
# |    episodes        | 2611      |
# |    fps             | 22        |
# |    time_elapsed    | 7382      |
# |    total_timesteps | 436468    |
# | train/             |           |
# |    actor_loss      | 3.07e+03  |
# |    critic_loss     | 512       |
# |    ent_coef        | 0.59      |
# |    ent_coef_loss   | 0.0479    |
# |    learning_rate   | 0.0003    |
# |    n_updates       | 218181    |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 167       |
# |    ep_rew_mean     | -8.02e+03 |
# | time/              |           |
# |    episodes        | 2612      |
# |    fps             | 22        |
# |    time_elapsed    | 7382      |
# |    total_timesteps | 436468    |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 167       |
# |    ep_rew_mean     | -8.03e+03 |
# | time/              |           |
# |    episodes        | 2613      |
# |    fps             | 22        |
# |    time_elapsed    | 7397      |
# |    total_timesteps | 436802    |
# | train/             |           |
# |    actor_loss      | 3.16e+03  |
# |    critic_loss     | 309       |
# |    ent_coef        | 0.58      |
# |    ent_coef_loss   | -0.0125   |
# |    learning_rate   | 0.0003    |
# |    n_updates       | 218348    |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 167       |
# |    ep_rew_mean     | -8.03e+03 |
# | time/              |           |
# |    episodes        | 2614      |
# |    fps             | 22        |
# |    time_elapsed    | 7397      |
# |    total_timesteps | 436802    |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 167       |
# |    ep_rew_mean     | -8.02e+03 |
# | time/              |           |
# |    episodes        | 2615      |
# |    fps             | 22        |
# |    time_elapsed    | 7415      |
# |    total_timesteps | 437136    |
# | train/             |           |
# |    actor_loss      | 3.11e+03  |
# |    critic_loss     | 401       |
# |    ent_coef        | 0.575     |
# |    ent_coef_loss   | -0.397    |
# |    learning_rate   | 0.0003    |
# |    n_updates       | 218515    |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 167       |
# |    ep_rew_mean     | -8.02e+03 |
# | time/              |           |
# |    episodes        | 2616      |
# |    fps             | 22        |
# |    time_elapsed    | 7415      |
# |    total_timesteps | 437136    |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 167       |
# |    ep_rew_mean     | -8.01e+03 |
# | time/              |           |
# |    episodes        | 2617      |
# |    fps             | 22        |
# |    time_elapsed    | 7431      |
# |    total_timesteps | 437470    |
# | train/             |           |
# |    actor_loss      | 3e+03     |
# |    critic_loss     | 396       |
# |    ent_coef        | 0.566     |
# |    ent_coef_loss   | 0.356     |
# |    learning_rate   | 0.0003    |
# |    n_updates       | 218682    |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 167       |
# |    ep_rew_mean     | -8.01e+03 |
# | time/              |           |
# |    episodes        | 2618      |
# |    fps             | 22        |
# |    time_elapsed    | 7431      |
# |    total_timesteps | 437470    |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 167       |
# |    ep_rew_mean     | -8.06e+03 |
# | time/              |           |
# |    episodes        | 2619      |
# |    fps             | 22        |
# |    time_elapsed    | 7446      |
# |    total_timesteps | 437804    |
# | train/             |           |
# |    actor_loss      | 3.14e+03  |
# |    critic_loss     | 349       |
# |    ent_coef        | 0.567     |
# |    ent_coef_loss   | 0.381     |
# |    learning_rate   | 0.0003    |
# |    n_updates       | 218849    |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 167       |
# |    ep_rew_mean     | -8.06e+03 |
# | time/              |           |
# |    episodes        | 2620      |
# |    fps             | 22        |
# |    time_elapsed    | 7446      |
# |    total_timesteps | 437804    |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 167       |
# |    ep_rew_mean     | -8.08e+03 |
# | time/              |           |
# |    episodes        | 2621      |
# |    fps             | 22        |
# |    time_elapsed    | 7461      |
# |    total_timesteps | 438138    |
# | train/             |           |
# |    actor_loss      | 3.11e+03  |
# |    critic_loss     | 311       |
# |    ent_coef        | 0.563     |
# |    ent_coef_loss   | 0.43      |
# |    learning_rate   | 0.0003    |
# |    n_updates       | 219016    |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 167       |
# |    ep_rew_mean     | -8.08e+03 |
# | time/              |           |
# |    episodes        | 2622      |
# |    fps             | 22        |
# |    time_elapsed    | 7461      |
# |    total_timesteps | 438138    |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 167       |
# |    ep_rew_mean     | -8.04e+03 |
# | time/              |           |
# |    episodes        | 2623      |
# |    fps             | 22        |
# |    time_elapsed    | 7478      |
# |    total_timesteps | 438472    |
# | train/             |           |
# |    actor_loss      | 3.08e+03  |
# |    critic_loss     | 436       |
# |    ent_coef        | 0.579     |
# |    ent_coef_loss   | -0.081    |
# |    learning_rate   | 0.0003    |
# |    n_updates       | 219183    |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 167       |
# |    ep_rew_mean     | -8.04e+03 |
# | time/              |           |
# |    episodes        | 2624      |
# |    fps             | 22        |
# |    time_elapsed    | 7478      |
# |    total_timesteps | 438472    |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 167       |
# |    ep_rew_mean     | -8.03e+03 |
# | time/              |           |
# |    episodes        | 2625      |
# |    fps             | 22        |
# |    time_elapsed    | 7496      |
# |    total_timesteps | 438806    |
# | train/             |           |
# |    actor_loss      | 3.13e+03  |
# |    critic_loss     | 372       |
# |    ent_coef        | 0.567     |
# |    ent_coef_loss   | 0.27      |
# |    learning_rate   | 0.0003    |
# |    n_updates       | 219350    |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 167       |
# |    ep_rew_mean     | -8.03e+03 |
# | time/              |           |
# |    episodes        | 2626      |
# |    fps             | 22        |
# ...
# |    ep_len_mean     | 167       |
# |    ep_rew_mean     | -3.24e+03 |
# | time/              |           |
# |    episodes        | 6065      |
# |    fps             | 23        |
# |    time_elapsed    | 31310     |
# |    total_timesteps | 1013286   |
# | train/             |           |
# |    actor_loss      | 1.09e+03  |
# |    critic_loss     | 11        |
# |    ent_coef        | 0.0896    |
# |    ent_coef_loss   | -1.44     |
# |    learning_rate   | 0.0003    |
# |    n_updates       | 506590    |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 167       |
# |    ep_rew_mean     | -3.24e+03 |
# | time/              |           |
# |    episodes        | 6066      |
# |    fps             | 23        |
# |    time_elapsed    | 31310     |
# |    total_timesteps | 1013286   |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 167       |
# |    ep_rew_mean     | -3.23e+03 |
# | time/              |           |
# |    episodes        | 6067      |
# |    fps             | 23        |
# |    time_elapsed    | 31323     |
# |    total_timesteps | 1013620   |
# | train/             |           |
# |    actor_loss      | 1.09e+03  |
# |    critic_loss     | 7.8       |
# |    ent_coef        | 0.0889    |
# |    ent_coef_loss   | 0.564     |
# |    learning_rate   | 0.0003    |
# |    n_updates       | 506757    |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 167       |
# |    ep_rew_mean     | -3.23e+03 |
# | time/              |           |
# |    episodes        | 6068      |
# |    fps             | 23        |
# |    time_elapsed    | 31323     |
# |    total_timesteps | 1013620   |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 167       |
# |    ep_rew_mean     | -3.22e+03 |
# | time/              |           |
# |    episodes        | 6069      |
# |    fps             | 23        |
# |    time_elapsed    | 31337     |
# |    total_timesteps | 1013954   |
# | train/             |           |
# |    actor_loss      | 1.12e+03  |
# |    critic_loss     | 15.9      |
# |    ent_coef        | 0.0895    |
# |    ent_coef_loss   | -0.61     |
# |    learning_rate   | 0.0003    |
# |    n_updates       | 506924    |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 167       |
# |    ep_rew_mean     | -3.22e+03 |
# | time/              |           |
# |    episodes        | 6070      |
# |    fps             | 23        |
# |    time_elapsed    | 31337     |
# |    total_timesteps | 1013954   |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 167       |
# |    ep_rew_mean     | -3.22e+03 |
# | time/              |           |
# |    episodes        | 6071      |
# |    fps             | 23        |
# |    time_elapsed    | 31350     |
# |    total_timesteps | 1014288   |
# | train/             |           |
# |    actor_loss      | 1.11e+03  |
# |    critic_loss     | 12.4      |
# |    ent_coef        | 0.0901    |
# |    ent_coef_loss   | -0.169    |
# |    learning_rate   | 0.0003    |
# |    n_updates       | 507091    |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 167       |
# |    ep_rew_mean     | -3.22e+03 |
# | time/              |           |
# |    episodes        | 6072      |
# |    fps             | 23        |
# |    time_elapsed    | 31350     |
# |    total_timesteps | 1014288   |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 167       |
# |    ep_rew_mean     | -3.21e+03 |
# | time/              |           |
# |    episodes        | 6073      |
# |    fps             | 23        |
# |    time_elapsed    | 31364     |
# |    total_timesteps | 1014622   |
# | train/             |           |
# |    actor_loss      | 1.1e+03   |
# |    critic_loss     | 20.6      |
# |    ent_coef        | 0.0903    |
# |    ent_coef_loss   | 0.716     |
# |    learning_rate   | 0.0003    |
# |    n_updates       | 507258    |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 167       |
# |    ep_rew_mean     | -3.21e+03 |
# | time/              |           |
# |    episodes        | 6074      |
# |    fps             | 23        |
# |    time_elapsed    | 31364     |
# |    total_timesteps | 1014622   |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 167       |
# |    ep_rew_mean     | -3.21e+03 |
# | time/              |           |
# |    episodes        | 6075      |
# |    fps             | 23        |
# |    time_elapsed    | 31377     |
# |    total_timesteps | 1014956   |
# | train/             |           |
# |    actor_loss      | 1.06e+03  |
# |    critic_loss     | 8.11      |
# |    ent_coef        | 0.0925    |
# |    ent_coef_loss   | 0.184     |
# |    learning_rate   | 0.0003    |
# |    n_updates       | 507425    |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 167       |
# |    ep_rew_mean     | -3.21e+03 |
# | time/              |           |
# |    episodes        | 6076      |
# |    fps             | 23        |
# |    time_elapsed    | 31377     |
# |    total_timesteps | 1014956   |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 167       |
# |    ep_rew_mean     | -3.21e+03 |
# | time/              |           |
# |    episodes        | 6077      |
# |    fps             | 23        |
# |    time_elapsed    | 31391     |
# |    total_timesteps | 1015290   |
# | train/             |           |
# |    actor_loss      | 1.08e+03  |
# |    critic_loss     | 16.2      |
# |    ent_coef        | 0.0912    |
# |    ent_coef_loss   | -0.233    |
# |    learning_rate   | 0.0003    |
# |    n_updates       | 507592    |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 167       |
# |    ep_rew_mean     | -3.21e+03 |
# | time/              |           |
# |    episodes        | 6078      |
# |    fps             | 23        |
# |    time_elapsed    | 31391     |
# |    total_timesteps | 1015290   |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 167       |
# |    ep_rew_mean     | -3.21e+03 |
# | time/              |           |
# |    episodes        | 6079      |
# |    fps             | 23        |
# |    time_elapsed    | 31404     |
# |    total_timesteps | 1015624   |
# | train/             |           |
# |    actor_loss      | 1.1e+03   |
# |    critic_loss     | 19.9      |
# |    ent_coef        | 0.0887    |
# |    ent_coef_loss   | -1.74     |
# |    learning_rate   | 0.0003    |
# |    n_updates       | 507759    |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 167       |
# |    ep_rew_mean     | -3.21e+03 |
# | time/              |           |
# |    episodes        | 6080      |
# |    fps             | 23        |
# |    time_elapsed    | 31404     |
# |    total_timesteps | 1015624   |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 167       |
# |    ep_rew_mean     | -3.22e+03 |
# | time/              |           |
# |    episodes        | 6081      |
# |    fps             | 23        |
# |    time_elapsed    | 31418     |
# |    total_timesteps | 1015958   |
# | train/             |           |
# |    actor_loss      | 1.09e+03  |
# |    critic_loss     | 7.31      |
# |    ent_coef        | 0.0886    |
# |    ent_coef_loss   | -0.208    |
# |    learning_rate   | 0.0003    |
# |    n_updates       | 507926    |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 167       |
# |    ep_rew_mean     | -3.22e+03 |
# | time/              |           |
# |    episodes        | 6082      |
# |    fps             | 23        |
# |    time_elapsed    | 31418     |
# |    total_timesteps | 1015958   |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 167       |
# |    ep_rew_mean     | -3.22e+03 |
# | time/              |           |
# |    episodes        | 6083      |
# |    fps             | 23        |
# |    time_elapsed    | 31431     |
# |    total_timesteps | 1016292   |
# | train/             |           |
# |    actor_loss      | 1.08e+03  |
# |    critic_loss     | 18.5      |
# |    ent_coef        | 0.0896    |
# |    ent_coef_loss   | 1.53      |
# |    learning_rate   | 0.0003    |
# |    n_updates       | 508093    |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 167       |
# |    ep_rew_mean     | -3.22e+03 |
# | time/              |           |
# |    episodes        | 6084      |
# |    fps             | 23        |
# |    time_elapsed    | 31431     |
# |    total_timesteps | 1016292   |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 167       |
# |    ep_rew_mean     | -3.22e+03 |
# | time/              |           |
# |    episodes        | 6085      |
# |    fps             | 23        |
# |    time_elapsed    | 31445     |
# |    total_timesteps | 1016626   |
# | train/             |           |
# |    actor_loss      | 1.07e+03  |
# |    critic_loss     | 12.5      |
# |    ent_coef        | 0.0887    |
# |    ent_coef_loss   | 0.48      |
# |    learning_rate   | 0.0003    |
# |    n_updates       | 508260    |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 167       |
# |    ep_rew_mean     | -3.22e+03 |
# | time/              |           |
# |    episodes        | 6086      |
# |    fps             | 23        |
# |    time_elapsed    | 31445     |
# |    total_timesteps | 1016626   |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 167       |
# |    ep_rew_mean     | -3.22e+03 |
# | time/              |           |
# |    episodes        | 6087      |
# |    fps             | 23        |
# |    time_elapsed    | 31458     |
# |    total_timesteps | 1016960   |
# | train/             |           |
# |    actor_loss      | 1.07e+03  |
# |    critic_loss     | 7.44      |
# |    ent_coef        | 0.0879    |
# |    ent_coef_loss   | -0.344    |
# |    learning_rate   | 0.0003    |
# |    n_updates       | 508427    |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 167       |
# |    ep_rew_mean     | -3.22e+03 |
# | time/              |           |
# |    episodes        | 6088      |
# |    fps             | 23        |
# |    time_elapsed    | 31458     |
# |    total_timesteps | 1016960   |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 167       |
# |    ep_rew_mean     | -3.23e+03 |
# | time/              |           |
# |    episodes        | 6089      |
# |    fps             | 23        |
# |    time_elapsed    | 31471     |
# |    total_timesteps | 1017294   |
# | train/             |           |
# |    actor_loss      | 1.09e+03  |
# |    critic_loss     | 14.3      |
# |    ent_coef        | 0.0885    |
# |    ent_coef_loss   | -1.97     |
# |    learning_rate   | 0.0003    |
# |    n_updates       | 508594    |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 167       |
# |    ep_rew_mean     | -3.23e+03 |
# | time/              |           |
# |    episodes        | 6090      |
# |    fps             | 23        |
# |    time_elapsed    | 31471     |
# |    total_timesteps | 1017294   |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 167       |
# |    ep_rew_mean     | -3.22e+03 |
# | time/              |           |
# |    episodes        | 6091      |
# |    fps             | 23        |
# |    time_elapsed    | 31485     |
# |    total_timesteps | 1017628   |
# | train/             |           |
# |    actor_loss      | 1.11e+03  |
# |    critic_loss     | 9.95      |
# |    ent_coef        | 0.0877    |
# |    ent_coef_loss   | 0.0966    |
# |    learning_rate   | 0.0003    |
# |    n_updates       | 508761    |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 167       |
# |    ep_rew_mean     | -3.22e+03 |
# | time/              |           |
# |    episodes        | 6092      |
# |    fps             | 23        |
# |    time_elapsed    | 31485     |
# |    total_timesteps | 1017628   |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 167       |
# |    ep_rew_mean     | -3.21e+03 |
# | time/              |           |
# |    episodes        | 6093      |
# |    fps             | 23        |
# |    time_elapsed    | 31498     |
# |    total_timesteps | 1017962   |
# | train/             |           |
# |    actor_loss      | 1.1e+03   |
# |    critic_loss     | 10.3      |
# |    ent_coef        | 0.0882    |
# |    ent_coef_loss   | 0.49      |
# |    learning_rate   | 0.0003    |
# |    n_updates       | 508928    |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 167       |
# |    ep_rew_mean     | -3.21e+03 |
# | time/              |           |
# |    episodes        | 6094      |
# |    fps             | 23        |
# |    time_elapsed    | 31498     |
# |    total_timesteps | 1017962   |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 167       |
# |    ep_rew_mean     | -3.21e+03 |
# | time/              |           |
# |    episodes        | 6095      |
# |    fps             | 23        |
# |    time_elapsed    | 31512     |
# |    total_timesteps | 1018296   |
# | train/             |           |
# |    actor_loss      | 1.1e+03   |
# |    critic_loss     | 8.59      |
# |    ent_coef        | 0.0914    |
# |    ent_coef_loss   | -0.839    |
# |    learning_rate   | 0.0003    |
# |    n_updates       | 509095    |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 167       |
# |    ep_rew_mean     | -3.21e+03 |
# | time/              |           |
# |    episodes        | 6096      |
# |    fps             | 23        |
# |    time_elapsed    | 31512     |
# |    total_timesteps | 1018296   |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 167       |
# |    ep_rew_mean     | -3.21e+03 |
# | time/              |           |
# |    episodes        | 6097      |
# |    fps             | 23        |
# |    time_elapsed    | 31525     |
# |    total_timesteps | 1018630   |
# | train/             |           |
# |    actor_loss      | 1.08e+03  |
# |    critic_loss     | 12.4      |
# |    ent_coef        | 0.0907    |
# |    ent_coef_loss   | -2.96     |
# |    learning_rate   | 0.0003    |
# |    n_updates       | 509262    |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 167       |
# |    ep_rew_mean     | -3.21e+03 |
# | time/              |           |
# |    episodes        | 6098      |
# |    fps             | 23        |
# |    time_elapsed    | 31525     |
# |    total_timesteps | 1018630   |
# ----------------------------------

# %%
# Final Save
model.save(model_dir / f"{session_name}_final")
model.save_replay_buffer(model_dir / f"{session_name}_final_replay_buffer")

# %% [markdown]
# # Evaluate (get KPIs)

# %%
# ==========================================
# 1. Configuration
# ==========================================

# Assuming the notebook is running from the same root directory as the training script
model_path = f"models/{session_name}/{session_name}_final.zip"
kpi_csv_save_path = kpi_dir / f"{session_name}.csv"

print(f"--- Evaluating {num_houses}-House Centralized SAC ---")

# ==========================================
# 2. Strict Single-Environment Initialization
# ==========================================

# Initialize without SubprocVecEnv for clean metric tracking
env = CityLearnEnv(schema_dict, central_agent=True)
env = NormalizedObservationWrapper(env)
env = StableBaselines3Wrapper(env)

# ==========================================
# 3. Model Loading & Execution
# ==========================================
if not os.path.exists(model_path):
    raise FileNotFoundError(f"Model not found at {model_path}. Verify the path.")

with patch_module_load_state_dict():
    model = SAC.load(model_path, env=env)
# Out:
# --- Evaluating 6-House Centralized SAC ---
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.

# %%
obs, _info = env.reset()
done = False
total_reward = 0
step_count = 0

action_history = []

print("Running deterministic rollout...")

while not done:
    # deterministic=True disables entropy/exploration noise, outputting the strict argmax policy
    action, _states = model.predict(obs, deterministic=True)
    action_history.append(action)

    # Safely unpack the step returns regardless of Gym/Gymnasium version
    step_returns = env.step(action)
    if len(step_returns) == 5:
        obs, reward, terminated, truncated, info = step_returns
        done = terminated or truncated
    else:
        obs, reward, done, info = step_returns

    # Handle reward unpacking based on environment wrapper behavior
    step_reward = (
        reward[0]
        if isinstance(reward, (list, tuple)) or (hasattr(reward, "shape") and len(reward.shape) > 0)
        else reward
    )
    total_reward += step_reward
    step_count += 1
# Out:
# Running deterministic rollout...

# %%
# Convert collected actions to a numpy array (Shape will be[Time, Num_Houses * Num_Actions])
action_history = np.array(action_history)

print(f"Rollout Complete. Total Steps: {step_count}")
print(f"Cumulative Episode Reward: {total_reward:.4f}")
# Out:
# Rollout Complete. Total Steps: 2207
# Cumulative Episode Reward: -226546.1963

# %%
# ==========================================
# 4. KPI Extraction
# ==========================================
# Extract the domain-specific metrics calculated natively by CityLearn
kpis = env.unwrapped.evaluate()
kpis = kpis.pivot(index="cost_function", columns="name", values="value").round(4)
kpis = kpis.dropna(how="all")


kpis.to_csv(kpi_csv_save_path)

print("\n=== CityLearn Key Performance Indicators ===")
display(kpis)
# Out:
# === CityLearn Key Performance Indicators ===
# name                                           Building_1  Building_2  \
# cost_function
# all_time_peak_average                                 NaN         NaN
# annual_normalized_unserved_energy_total            0.0151      0.0189
# carbon_emissions_total                             0.8705      1.0735
# cost_total                                         0.8316      1.0535
# daily_one_minus_load_factor_average                   NaN         NaN
# daily_peak_average                                    NaN         NaN
# discomfort_cold_delta_average                      0.6983      0.2807
# discomfort_cold_delta_maximum                     12.0519     10.3197
# discomfort_cold_delta_minimum                      0.0000      0.0000
# discomfort_cold_proportion                         0.1071      0.0562
# discomfort_hot_delta_average                       0.5639      0.4215
# discomfort_hot_delta_maximum                       6.8488      7.0279
# discomfort_hot_delta_minimum                       0.0000      0.0000
# discomfort_hot_proportion                          0.0395      0.0303
# discomfort_proportion                              0.1466      0.0865
# electricity_consumption_total                      0.8664      1.0667
# monthly_one_minus_load_factor_average                 NaN         NaN
# one_minus_thermal_resilience_proportion            0.6905      1.0000
# power_outage_normalized_unserved_energy_total      0.6431      0.7259
# ramping_average                                       NaN         NaN
# zero_net_energy                                    0.8577      1.0707
#
# name                                           Building_3  Building_4  \
# cost_function
# all_time_peak_average                                 NaN         NaN
# annual_normalized_unserved_energy_total            0.0116      0.0152
# carbon_emissions_total                             0.9293      0.7964
# cost_total                                         0.8973      0.7685
# daily_one_minus_load_factor_average                   NaN         NaN
# daily_peak_average                                    NaN         NaN
# discomfort_cold_delta_average                      0.1882      0.3040
# discomfort_cold_delta_maximum                      5.7034     11.6556
# discomfort_cold_delta_minimum                      0.0000      0.0000
# discomfort_cold_proportion                         0.0465      0.0413
# discomfort_hot_delta_average                       0.5975      0.6540
# discomfort_hot_delta_maximum                       4.8751      9.0565
# discomfort_hot_delta_minimum                       0.0000      0.0000
# discomfort_hot_proportion                          0.0317      0.0446
# discomfort_proportion                              0.0783      0.0858
# electricity_consumption_total                      0.9248      0.7963
# monthly_one_minus_load_factor_average                 NaN         NaN
# one_minus_thermal_resilience_proportion            0.8750      0.6744
# power_outage_normalized_unserved_energy_total      0.6041      0.6140
# ramping_average                                       NaN         NaN
# zero_net_energy                                    0.9222      0.7818
#
# name                                           Building_5  Building_6  \
# cost_function
# all_time_peak_average                                 NaN         NaN
# annual_normalized_unserved_energy_total            0.0200      0.0150
# carbon_emissions_total                             0.9825      0.9074
# cost_total                                         0.9730      0.8759
# daily_one_minus_load_factor_average                   NaN         NaN
# daily_peak_average                                    NaN         NaN
# discomfort_cold_delta_average                      0.1772      0.6343
# discomfort_cold_delta_maximum                      6.3770     14.8348
# discomfort_cold_delta_minimum                      0.0000      0.0000
# discomfort_cold_proportion                         0.0243      0.0877
# discomfort_hot_delta_average                       0.7669      0.4957
# discomfort_hot_delta_maximum                      13.0271      9.0567
# discomfort_hot_delta_minimum                       0.0000      0.0000
# discomfort_hot_proportion                          0.1012      0.0302
# discomfort_proportion                              0.1255      0.1179
# electricity_consumption_total                      0.9816      0.9016
# monthly_one_minus_load_factor_average                 NaN         NaN
# one_minus_thermal_resilience_proportion            1.0000      0.8780
# power_outage_normalized_unserved_energy_total      0.7961      0.6567
# ramping_average                                       NaN         NaN
# zero_net_energy                                    0.9826      0.9007
#
# name                                           District
# cost_function
# all_time_peak_average                            0.8488
# annual_normalized_unserved_energy_total          0.0160
# carbon_emissions_total                           0.9266
# cost_total                                       0.9000
# daily_one_minus_load_factor_average              0.9972
# daily_peak_average                               0.9025
# discomfort_cold_delta_average                    0.3804
# discomfort_cold_delta_maximum                   10.1571
# discomfort_cold_delta_minimum                    0.0000
# discomfort_cold_proportion                       0.0605
# discomfort_hot_delta_average                     0.5832
# discomfort_hot_delta_maximum                     8.3153
# discomfort_hot_delta_minimum                     0.0000
# discomfort_hot_proportion                        0.0463
# discomfort_proportion                            0.1068
# electricity_consumption_total                    0.9229
# monthly_one_minus_load_factor_average            1.0011
# one_minus_thermal_resilience_proportion          0.8530
# power_outage_normalized_unserved_energy_total    0.6733
# ramping_average                                  1.0081
# zero_net_energy                                  0.9193

# %% [markdown]
# # Investigate agent behavior

# %%
# ==========================================
# 5. Agent Behavior Plotting
# ==========================================
print("\n=== Generating Behavior Plots for Each House ===")

T = len(action_history)
start_date = pd.Timestamp("2023-08-01 00:00:00")
timestamps = pd.date_range(start=start_date, periods=T, freq="h")

# A centralized agent concatenates all building actions into a single array.
# For example, 6 houses with 3 actions each will have a shape of (T, 18).
num_actions_total = action_history.shape[1]
actions_per_building = num_actions_total // num_houses

# Loop and plot for every individual building
for b_idx in range(num_houses):
    building = env.unwrapped.buildings[b_idx]

    # 1. Telemetry specific to current building
    indoor_temp = building.indoor_dry_bulb_temperature[:T]
    setpoint = building.indoor_dry_bulb_temperature_cooling_set_point[:T]
    soc = building.electrical_storage.soc[:T]
    net_load = building.net_electricity_consumption[:T]

    # 2. Extract action indices mapped to this specific building
    # Assuming standard order: [DHW, Battery, Cooling]
    b_action_start = b_idx * actions_per_building
    bat_action_idx = b_action_start + 1
    cool_action_idx = b_action_start + 2

    fig, axs = plt.subplots(3, 1, figsize=(14, 12), sharex=True)

    # --- Plot 1: HVAC ---
    color_temp = "tab:red"
    axs[0].plot(timestamps, indoor_temp, label="Indoor Temp (°C)", color=color_temp)
    axs[0].plot(timestamps, setpoint, label="Setpoint", color="darkred", linestyle="--")
    axs[0].set_ylabel("Temperature (°C)", color=color_temp)

    ax0_twin = axs[0].twinx()
    color_act = "tab:blue"
    ax0_twin.fill_between(
        timestamps,
        0,
        action_history[:, cool_action_idx],
        alpha=0.3,
        color=color_act,
        label="Cooling Action",
    )
    ax0_twin.set_ylabel("Cooling Action (0 to 1)", color=color_act)
    axs[0].set_title(f"Building {b_idx + 1} - HVAC Diagnostics: State vs. Action")

    l1, lab1 = axs[0].get_legend_handles_labels()
    l2, lab2 = ax0_twin.get_legend_handles_labels()
    axs[0].legend(l1 + l2, lab1 + lab2, loc="upper left")

    # --- Plot 2: Battery ---
    color_soc = "tab:green"
    axs[1].plot(timestamps, soc, label="Battery SOC", color=color_soc, linewidth=2)
    axs[1].set_ylabel("State of Charge", color=color_soc)

    ax1_twin = axs[1].twinx()
    color_b_act = "tab:purple"
    ax1_twin.step(
        timestamps,
        action_history[:, bat_action_idx],
        where="post",
        label="Battery Action",
        color=color_b_act,
    )
    ax1_twin.axhline(0, color="black", linewidth=1, linestyle="--")
    ax1_twin.set_ylabel("Action (-1 to 1)", color=color_b_act)
    axs[1].set_title(f"Building {b_idx + 1} - Battery Diagnostics: SOC vs. Action")

    l1, lab1 = axs[1].get_legend_handles_labels()
    l2, lab2 = ax1_twin.get_legend_handles_labels()
    axs[1].legend(l1 + l2, lab1 + lab2, loc="upper left")

    # --- Plot 3: Net Grid Load ---
    axs[2].plot(timestamps, net_load, label="Net Grid Load (kWh)", color="black")
    axs[2].axhline(0, color="gray", linewidth=1, linestyle="--")
    axs[2].set_ylabel("Consumption (kWh)")
    axs[2].set_title(f"Building {b_idx + 1} - System Outcome: Net Electricity Consumption")
    axs[2].legend(loc="upper left")
    axs[2].grid(True, alpha=0.4)

    axs[2].xaxis.set_major_formatter(mdates.DateFormatter("%b %d\n%H:%M"))
    plt.xticks(rotation=0)
    plt.xlim(timestamps[0], timestamps[48])
    plt.tight_layout()
    plt.show()
# Out:
# === Generating Behavior Plots for Each House ===

# %%
# ==========================================
# 6. Centralized District-Level Visualization
# ==========================================
# Because this is a centralized agent, looking at the entire district is highly relevant.

print("\n=== Generating District-Level Aggregated Plot ===")
fig, ax = plt.subplots(figsize=(14, 4))

# Summing up the grid loads of all houses
district_net_load = sum(
    [env.unwrapped.buildings[i].net_electricity_consumption[:T] for i in range(num_houses)]
)

ax.plot(timestamps, district_net_load, label="District Net Grid Load (kWh)", color="black")
ax.axhline(0, color="gray", linewidth=1, linestyle="--")
ax.set_ylabel("Aggregated Consumption (kWh)")
ax.set_title(f"District-Level System Outcome (All {num_houses} Houses Combined)")
ax.legend(loc="upper left")
ax.grid(True, alpha=0.4)

ax.xaxis.set_major_formatter(mdates.DateFormatter("%b %d\n%H:%M"))
plt.xticks(rotation=0)
plt.xlim(timestamps[0], timestamps[168])
plt.tight_layout()
plt.show()
# Out:
# === Generating District-Level Aggregated Plot ===
