# %%
import os
import glob
import copy
from pathlib import Path
import pandas as pd
import numpy as np

# SB3 Imports
from stable_baselines3 import SAC
from stable_baselines3.common.callbacks import CheckpointCallback
from stable_baselines3.common.vec_env import SubprocVecEnv
from stable_baselines3.common.monitor import Monitor

# CityLearn Imports
from citylearn.citylearn import CityLearnEnv
from citylearn.wrappers import NormalizedObservationWrapper, StableBaselines3Wrapper

# %% [markdown]
# # Train

# %%
def make_env(schema_dict, episode_time_steps):
    """
    Factory function for SubprocVecEnv to instantiate separate environments.
    Rendering and logging parameters are removed to maximize simulation speed.
    """

    def _init():
        env = CityLearnEnv(
            schema=schema_dict, central_agent=True, episode_time_steps=episode_time_steps
        )
        env = NormalizedObservationWrapper(env)
        env = StableBaselines3Wrapper(env)
        env = Monitor(env)
        return env

    return _init

# %%
# ------------------------------------------------------------------
# 0. Global Parameters
# ------------------------------------------------------------------
num_houses = 1
num_cpu = 2  # Set this to the number of physical cores available
episode_length = 168

print(f"\n{'='*60}")
print(f"INITIALIZING VECTORIZED EXPERIMENT: {num_houses} HOUSE(S) | {num_cpu} WORKERS")
print(f"{'='*60}\n")

# ------------------------------------------------------------------
# 1. Configuration & Paths
# ------------------------------------------------------------------
base_schema = "citylearn_challenge_2023_phase_3_1"
session_name = f"{num_houses}_house_sac_vectorized_new_reward"

tensorboard_log_dir = Path.cwd() / "training_logs"
model_dir = Path.cwd() / "models" / session_name
kpi_dir = Path.cwd() / "kpi"
os.makedirs(model_dir, exist_ok=True)
os.makedirs(kpi_dir, exist_ok=True)
os.makedirs(tensorboard_log_dir, exist_ok=True)

# ------------------------------------------------------------------
# 2. Dynamic Schema Extraction
# ------------------------------------------------------------------
temp_env = CityLearnEnv(schema=base_schema)
schema_dict = copy.deepcopy(temp_env.schema)
building_names = list(schema_dict["buildings"].keys())

if num_houses < len(building_names):
    target_buildings = building_names[:num_houses]
    schema_dict["buildings"] = {b: schema_dict["buildings"][b] for b in target_buildings}

schema_dict["reward_function"]["type"] = "citylearn.reward_function.SolarPenaltyAndComfortReward"
# schema_dict["reward_function"]["attributes"]["coefficients"] = (0.1, 1.0)

# ------------------------------------------------------------------
# 3. Environment Vectorization
# ------------------------------------------------------------------
env_fns = [make_env(schema_dict, episode_length) for _ in range(num_cpu)]
env = SubprocVecEnv(env_fns)

# ------------------------------------------------------------------
# 4. Hyperparameter Scaling & Optimization
# ------------------------------------------------------------------
if num_houses == 1:
    net_arch = [256, 256]
    batch_size = 256
elif num_houses == 3:
    net_arch = [256, 256]
    batch_size = 256
else:
    net_arch = [256, 256, 128]
    batch_size = 512

# ------------------------------------------------------------------
# 5. Checkpoint Callback Setup
# ------------------------------------------------------------------
save_freq_episodes = 200
# Adjust save frequency for parallel environments
save_freq_steps = max((episode_length * save_freq_episodes) // num_cpu, 1)

checkpoint_callback = CheckpointCallback(
    save_freq=save_freq_steps,
    save_path=model_dir,
    name_prefix="sac_model",
    save_replay_buffer=True,
    save_vecnormalize=True,
)
# Out:
# ============================================================
# INITIALIZING VECTORIZED EXPERIMENT: 1 HOUSE(S) | 2 WORKERS
# ============================================================
# INFO:root:Go here /home/ntpt/.cache/citylearn/v2.5.0/datasets/citylearn_challenge_2023_phase_3_1/schema.json

# %%
# ------------------------------------------------------------------
# 6. Model Initialization or Resumption
# ------------------------------------------------------------------
import torch
import contextlib


@contextlib.contextmanager
def patch_module_load_state_dict():
    """
    Context manager to intercept PyTorch's state_dict loading.
    Strips the `_orig_mod.` prefix generated by torch.compile()
    so compiled checkpoints can map to uncompiled architectures natively.
    """
    original_load = torch.nn.Module.load_state_dict

    def patched_load(self, state_dict, *args, **kwargs):
        clean_dict = {k.replace("_orig_mod.", ""): v for k, v in state_dict.items()}
        return original_load(self, clean_dict, *args, **kwargs)

    try:
        torch.nn.Module.load_state_dict = patched_load
        yield
    finally:
        torch.nn.Module.load_state_dict = original_load

# %%
list_of_files = glob.glob(f"{model_dir}/*.zip")
latest_model_path = max(list_of_files, key=os.path.getctime) if list_of_files else None

if latest_model_path:
    print(f"Resuming {num_houses}-house training from checkpoint: {latest_model_path}")

    # 1. Load natively while intercepting and cleaning the state_dict
    with patch_module_load_state_dict():
        model = SAC.load(latest_model_path, env=env, tensorboard_log=tensorboard_log_dir)

    # 2. Re-apply torch.compile for the resumed training session
    model.policy.actor = torch.compile(model.policy.actor)
    model.policy.critic = torch.compile(model.policy.critic)

    # 3. Restore the replay buffer
    replay_buffer_path = latest_model_path.replace(".zip", "_replay_buffer.pkl")
    if os.path.exists(replay_buffer_path):
        model.load_replay_buffer(replay_buffer_path)
        print("Replay buffer loaded successfully.")

    reset_steps = False
else:
    print(f"Initializing new {num_houses}-house vectorized model...")
    model = SAC(
        "MlpPolicy",
        env,
        policy_kwargs=dict(net_arch=net_arch),
        batch_size=batch_size,
        buffer_size=100000,
        verbose=1,
        tensorboard_log=tensorboard_log_dir,
    )

    model.policy.actor = torch.compile(model.policy.actor)
    model.policy.critic = torch.compile(model.policy.critic)

    reset_steps = True
# Out:
# Resuming 1-house training from checkpoint: /home/ntpt/Documents/Uni/Big_Data/GroupWork/FRL_Smart_Grid/baseline/models/1_house_sac_vectorized_new_reward/1_house_sac_vectorized_new_reward_final.zip
# Replay buffer loaded successfully.

# %%
# ------------------------------------------------------------------
# 7. Execution
# ------------------------------------------------------------------
total_timesteps = 200000

print(f"Target Timesteps: {total_timesteps}")
model.learn(
    total_timesteps=total_timesteps,
    callback=checkpoint_callback,
    tb_log_name=session_name,
    reset_num_timesteps=reset_steps,
    log_interval=1,  # Forces logging after every episode completion
)
# Out:
# Target Timesteps: 200000
# Logging to /home/ntpt/Documents/Uni/Big_Data/GroupWork/FRL_Smart_Grid/baseline/training_logs/1_house_sac_vectorized_new_reward_1
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 167       |
# |    ep_rew_mean     | -1.31e+03 |
# | time/              |           |
# |    episodes        | 4929      |
# |    fps             | 50        |
# |    time_elapsed    | 6         |
# |    total_timesteps | 824014    |
# | train/             |           |
# |    actor_loss      | 892       |
# |    critic_loss     | 107       |
# |    ent_coef        | 1.56      |
# |    ent_coef_loss   | 0.00973   |
# |    learning_rate   | 0.0003    |
# |    n_updates       | 411955    |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 167       |
# |    ep_rew_mean     | -1.31e+03 |
# | time/              |           |
# |    episodes        | 4930      |
# |    fps             | 50        |
# |    time_elapsed    | 6         |
# |    total_timesteps | 824014    |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 167       |
# |    ep_rew_mean     | -1.31e+03 |
# | time/              |           |
# |    episodes        | 4931      |
# |    fps             | 54        |
# |    time_elapsed    | 12        |
# |    total_timesteps | 824348    |
# | train/             |           |
# |    actor_loss      | 922       |
# |    critic_loss     | 83.7      |
# |    ent_coef        | 1.54      |
# |    ent_coef_loss   | 0.0194    |
# |    learning_rate   | 0.0003    |
# |    n_updates       | 412122    |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 167       |
# |    ep_rew_mean     | -1.31e+03 |
# | time/              |           |
# |    episodes        | 4932      |
# |    fps             | 54        |
# |    time_elapsed    | 12        |
# |    total_timesteps | 824348    |
# ----------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 167      |
# |    ep_rew_mean     | -1.3e+03 |
# | time/              |          |
# |    episodes        | 4933     |
# |    fps             | 55       |
# |    time_elapsed    | 17       |
# |    total_timesteps | 824682   |
# | train/             |          |
# |    actor_loss      | 889      |
# |    critic_loss     | 108      |
# |    ent_coef        | 1.55     |
# |    ent_coef_loss   | 0.078    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 412289   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 167      |
# |    ep_rew_mean     | -1.3e+03 |
# | time/              |          |
# |    episodes        | 4934     |
# |    fps             | 55       |
# |    time_elapsed    | 17       |
# |    total_timesteps | 824682   |
# ---------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 167       |
# |    ep_rew_mean     | -1.31e+03 |
# | time/              |           |
# |    episodes        | 4935      |
# |    fps             | 56        |
# |    time_elapsed    | 23        |
# |    total_timesteps | 825016    |
# | train/             |           |
# |    actor_loss      | 861       |
# |    critic_loss     | 100       |
# |    ent_coef        | 1.53      |
# |    ent_coef_loss   | -0.0549   |
# |    learning_rate   | 0.0003    |
# |    n_updates       | 412456    |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 167       |
# |    ep_rew_mean     | -1.31e+03 |
# | time/              |           |
# |    episodes        | 4936      |
# |    fps             | 56        |
# |    time_elapsed    | 23        |
# |    total_timesteps | 825016    |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 167       |
# |    ep_rew_mean     | -1.31e+03 |
# | time/              |           |
# |    episodes        | 4937      |
# |    fps             | 56        |
# |    time_elapsed    | 29        |
# |    total_timesteps | 825350    |
# | train/             |           |
# |    actor_loss      | 868       |
# |    critic_loss     | 97.8      |
# |    ent_coef        | 1.54      |
# |    ent_coef_loss   | 0.0257    |
# |    learning_rate   | 0.0003    |
# |    n_updates       | 412623    |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 167       |
# |    ep_rew_mean     | -1.31e+03 |
# | time/              |           |
# |    episodes        | 4938      |
# |    fps             | 56        |
# |    time_elapsed    | 29        |
# |    total_timesteps | 825350    |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 167       |
# |    ep_rew_mean     | -1.29e+03 |
# | time/              |           |
# |    episodes        | 4939      |
# |    fps             | 56        |
# |    time_elapsed    | 35        |
# |    total_timesteps | 825684    |
# | train/             |           |
# |    actor_loss      | 855       |
# |    critic_loss     | 112       |
# |    ent_coef        | 1.54      |
# |    ent_coef_loss   | -0.0753   |
# |    learning_rate   | 0.0003    |
# |    n_updates       | 412790    |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 167       |
# |    ep_rew_mean     | -1.29e+03 |
# | time/              |           |
# |    episodes        | 4940      |
# |    fps             | 56        |
# |    time_elapsed    | 35        |
# |    total_timesteps | 825684    |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 167       |
# |    ep_rew_mean     | -1.29e+03 |
# | time/              |           |
# |    episodes        | 4941      |
# |    fps             | 56        |
# |    time_elapsed    | 41        |
# |    total_timesteps | 826018    |
# | train/             |           |
# |    actor_loss      | 886       |
# |    critic_loss     | 86.4      |
# |    ent_coef        | 1.54      |
# |    ent_coef_loss   | 0.0631    |
# |    learning_rate   | 0.0003    |
# |    n_updates       | 412957    |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 167       |
# |    ep_rew_mean     | -1.29e+03 |
# | time/              |           |
# |    episodes        | 4942      |
# |    fps             | 56        |
# |    time_elapsed    | 41        |
# |    total_timesteps | 826018    |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 167       |
# |    ep_rew_mean     | -1.29e+03 |
# | time/              |           |
# |    episodes        | 4943      |
# |    fps             | 57        |
# |    time_elapsed    | 46        |
# |    total_timesteps | 826352    |
# | train/             |           |
# |    actor_loss      | 883       |
# |    critic_loss     | 97        |
# |    ent_coef        | 1.55      |
# |    ent_coef_loss   | -0.0144   |
# |    learning_rate   | 0.0003    |
# |    n_updates       | 413124    |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 167       |
# |    ep_rew_mean     | -1.29e+03 |
# | time/              |           |
# |    episodes        | 4944      |
# |    fps             | 57        |
# |    time_elapsed    | 46        |
# |    total_timesteps | 826352    |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 167       |
# |    ep_rew_mean     | -1.29e+03 |
# | time/              |           |
# |    episodes        | 4945      |
# |    fps             | 57        |
# |    time_elapsed    | 52        |
# |    total_timesteps | 826686    |
# | train/             |           |
# |    actor_loss      | 879       |
# |    critic_loss     | 86.3      |
# |    ent_coef        | 1.55      |
# |    ent_coef_loss   | 0.0315    |
# |    learning_rate   | 0.0003    |
# |    n_updates       | 413291    |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 167       |
# |    ep_rew_mean     | -1.29e+03 |
# | time/              |           |
# |    episodes        | 4946      |
# |    fps             | 57        |
# |    time_elapsed    | 52        |
# |    total_timesteps | 826686    |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 167       |
# |    ep_rew_mean     | -1.28e+03 |
# | time/              |           |
# |    episodes        | 4947      |
# |    fps             | 57        |
# |    time_elapsed    | 57        |
# |    total_timesteps | 827020    |
# | train/             |           |
# |    actor_loss      | 879       |
# |    critic_loss     | 93.5      |
# |    ent_coef        | 1.54      |
# |    ent_coef_loss   | 0.0146    |
# |    learning_rate   | 0.0003    |
# |    n_updates       | 413458    |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 167       |
# |    ep_rew_mean     | -1.28e+03 |
# | time/              |           |
# |    episodes        | 4948      |
# |    fps             | 57        |
# |    time_elapsed    | 57        |
# |    total_timesteps | 827020    |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 167       |
# |    ep_rew_mean     | -1.29e+03 |
# | time/              |           |
# |    episodes        | 4949      |
# |    fps             | 57        |
# |    time_elapsed    | 63        |
# |    total_timesteps | 827354    |
# | train/             |           |
# |    actor_loss      | 902       |
# |    critic_loss     | 137       |
# |    ent_coef        | 1.54      |
# |    ent_coef_loss   | 0.0816    |
# |    learning_rate   | 0.0003    |
# |    n_updates       | 413625    |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 167       |
# |    ep_rew_mean     | -1.29e+03 |
# | time/              |           |
# |    episodes        | 4950      |
# |    fps             | 57        |
# |    time_elapsed    | 63        |
# |    total_timesteps | 827354    |
# ----------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 167      |
# |    ep_rew_mean     | -1.3e+03 |
# | time/              |          |
# |    episodes        | 4951     |
# |    fps             | 57       |
# |    time_elapsed    | 69       |
# |    total_timesteps | 827688   |
# | train/             |          |
# |    actor_loss      | 855      |
# |    critic_loss     | 107      |
# |    ent_coef        | 1.53     |
# |    ent_coef_loss   | 0.023    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 413792   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 167      |
# |    ep_rew_mean     | -1.3e+03 |
# | time/              |          |
# |    episodes        | 4952     |
# |    fps             | 57       |
# |    time_elapsed    | 69       |
# |    total_timesteps | 827688   |
# ---------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 167       |
# |    ep_rew_mean     | -1.31e+03 |
# | time/              |           |
# |    episodes        | 4953      |
# |    fps             | 57        |
# |    time_elapsed    | 74        |
# |    total_timesteps | 828022    |
# | train/             |           |
# |    actor_loss      | 856       |
# |    critic_loss     | 95.2      |
# |    ent_coef        | 1.51      |
# |    ent_coef_loss   | -0.0561   |
# |    learning_rate   | 0.0003    |
# |    n_updates       | 413959    |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 167       |
# |    ep_rew_mean     | -1.31e+03 |
# | time/              |           |
# |    episodes        | 4954      |
# |    fps             | 57        |
# |    time_elapsed    | 74        |
# |    total_timesteps | 828022    |
# ----------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 167      |
# |    ep_rew_mean     | -1.3e+03 |
# | time/              |          |
# |    episodes        | 4955     |
# |    fps             | 58       |
# |    time_elapsed    | 80       |
# |    total_timesteps | 828356   |
# | train/             |          |
# |    actor_loss      | 849      |
# |    critic_loss     | 111      |
# |    ent_coef        | 1.51     |
# |    ent_coef_loss   | 0.0357   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 414126   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 167      |
# |    ep_rew_mean     | -1.3e+03 |
# | time/              |          |
# |    episodes        | 4956     |
# |    fps             | 58       |
# |    time_elapsed    | 80       |
# |    total_timesteps | 828356   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 167      |
# |    ep_rew_mean     | -1.3e+03 |
# | time/              |          |
# |    episodes        | 4957     |
# |    fps             | 58       |
# |    time_elapsed    | 86       |
# |    total_timesteps | 828690   |
# | train/             |          |
# |    actor_loss      | 862      |
# |    critic_loss     | 87.5     |
# |    ent_coef        | 1.52     |
# |    ent_coef_loss   | 0.036    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 414293   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 167      |
# |    ep_rew_mean     | -1.3e+03 |
# | time/              |          |
# |    episodes        | 4958     |
# |    fps             | 58       |
# |    time_elapsed    | 86       |
# |    total_timesteps | 828690   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 167      |
# |    ep_rew_mean     | -1.3e+03 |
# | time/              |          |
# |    episodes        | 4959     |
# |    fps             | 58       |
# |    time_elapsed    | 92       |
# |    total_timesteps | 829024   |
# | train/             |          |
# |    actor_loss      | 843      |
# |    critic_loss     | 112      |
# |    ent_coef        | 1.52     |
# |    ent_coef_loss   | 0.0352   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 414460   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 167      |
# |    ep_rew_mean     | -1.3e+03 |
# | time/              |          |
# |    episodes        | 4960     |
# |    fps             | 58       |
# |    time_elapsed    | 92       |
# |    total_timesteps | 829024   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 167      |
# |    ep_rew_mean     | -1.3e+03 |
# | time/              |          |
# |    episodes        | 4961     |
# |    fps             | 57       |
# |    time_elapsed    | 98       |
# |    total_timesteps | 829358   |
# | train/             |          |
# |    actor_loss      | 893      |
# |    critic_loss     | 131      |
# |    ent_coef        | 1.53     |
# |    ent_coef_loss   | -0.0538  |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 414627   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 167      |
# |    ep_rew_mean     | -1.3e+03 |
# | time/              |          |
# |    episodes        | 4962     |
# |    fps             | 57       |
# |    time_elapsed    | 98       |
# |    total_timesteps | 829358   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 167      |
# |    ep_rew_mean     | -1.3e+03 |
# | time/              |          |
# |    episodes        | 4963     |
# |    fps             | 58       |
# |    time_elapsed    | 103      |
# |    total_timesteps | 829692   |
# | train/             |          |
# |    actor_loss      | 852      |
# |    critic_loss     | 106      |
# |    ent_coef        | 1.53     |
# |    ent_coef_loss   | -0.0218  |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 414794   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 167      |
# |    ep_rew_mean     | -1.3e+03 |
# | time/              |          |
# |    episodes        | 4964     |
# |    fps             | 57       |
# |    time_elapsed    | 103      |
# |    total_timesteps | 829692   |
# ---------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 167       |
# |    ep_rew_mean     | -1.29e+03 |
# | time/              |           |
# |    episodes        | 4965      |
# |    fps             | 58        |
# |    time_elapsed    | 109       |
# |    total_timesteps | 830026    |
# | train/             |           |
# |    actor_loss      | 843       |
# |    critic_loss     | 88.4      |
# |    ent_coef        | 1.54      |
# |    ent_coef_loss   | -0.0499   |
# |    learning_rate   | 0.0003    |
# |    n_updates       | 414961    |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 167       |
# |    ep_rew_mean     | -1.29e+03 |
# | time/              |           |
# |    episodes        | 4966      |
# |    fps             | 58        |
# |    time_elapsed    | 109       |
# |    total_timesteps | 830026    |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 167       |
# |    ep_rew_mean     | -1.29e+03 |
# | time/              |           |
# |    episodes        | 4967      |
# |    fps             | 58        |
# |    time_elapsed    | 114       |
# |    total_timesteps | 830360    |
# | train/             |           |
# |    actor_loss      | 864       |
# |    critic_loss     | 124       |
# |    ent_coef        | 1.54      |
# |    ent_coef_loss   | 0.0771    |
# |    learning_rate   | 0.0003    |
# |    n_updates       | 415128    |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 167       |
# |    ep_rew_mean     | -1.29e+03 |
# | time/              |           |
# |    episodes        | 4968      |
# |    fps             | 58        |
# |    time_elapsed    | 114       |
# |    total_timesteps | 830360    |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 167       |
# |    ep_rew_mean     | -1.28e+03 |
# | time/              |           |
# |    episodes        | 4969      |
# |    fps             | 58        |
# |    time_elapsed    | 120       |
# |    total_timesteps | 830694    |
# | train/             |           |
# |    actor_loss      | 875       |
# |    critic_loss     | 104       |
# |    ent_coef        | 1.53      |
# |    ent_coef_loss   | 0.0551    |
# |    learning_rate   | 0.0003    |
# |    n_updates       | 415295    |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 167       |
# |    ep_rew_mean     | -1.28e+03 |
# | time/              |           |
# |    episodes        | 4970      |
# |    fps             | 58        |
# |    time_elapsed    | 120       |
# |    total_timesteps | 830694    |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 167       |
# |    ep_rew_mean     | -1.28e+03 |
# | time/              |           |
# |    episodes        | 4971      |
# |    fps             | 58        |
# |    time_elapsed    | 125       |
# |    total_timesteps | 831028    |
# | train/             |           |
# |    actor_loss      | 840       |
# |    critic_loss     | 101       |
# |    ent_coef        | 1.52      |
# |    ent_coef_loss   | -0.000342 |
# |    learning_rate   | 0.0003    |
# |    n_updates       | 415462    |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 167       |
# |    ep_rew_mean     | -1.28e+03 |
# | time/              |           |
# |    episodes        | 4972      |
# |    fps             | 58        |
# |    time_elapsed    | 125       |
# |    total_timesteps | 831028    |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 167       |
# |    ep_rew_mean     | -1.28e+03 |
# | time/              |           |
# |    episodes        | 4973      |
# |    fps             | 58        |
# |    time_elapsed    | 131       |
# |    total_timesteps | 831362    |
# | train/             |           |
# |    actor_loss      | 873       |
# |    critic_loss     | 89.1      |
# |    ent_coef        | 1.52      |
# |    ent_coef_loss   | -0.0956   |
# |    learning_rate   | 0.0003    |
# |    n_updates       | 415629    |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 167       |
# |    ep_rew_mean     | -1.28e+03 |
# | time/              |           |
# |    episodes        | 4974      |
# |    fps             | 58        |
# |    time_elapsed    | 131       |
# |    total_timesteps | 831362    |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 167       |
# |    ep_rew_mean     | -1.29e+03 |
# | time/              |           |
# |    episodes        | 4975      |
# |    fps             | 58        |
# |    time_elapsed    | 136       |
# |    total_timesteps | 831696    |
# | train/             |           |
# |    actor_loss      | 850       |
# |    critic_loss     | 99.4      |
# |    ent_coef        | 1.53      |
# |    ent_coef_loss   | 0.0164    |
# |    learning_rate   | 0.0003    |
# |    n_updates       | 415796    |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 167       |
# |    ep_rew_mean     | -1.29e+03 |
# | time/              |           |
# |    episodes        | 4976      |
# |    fps             | 58        |
# |    time_elapsed    | 136       |
# |    total_timesteps | 831696    |
# ----------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 167      |
# |    ep_rew_mean     | -1.3e+03 |
# | time/              |          |
# |    episodes        | 4977     |
# |    fps             | 58       |
# |    time_elapsed    | 142      |
# |    total_timesteps | 832030   |
# | train/             |          |
# |    actor_loss      | 844      |
# |    critic_loss     | 84       |
# |    ent_coef        | 1.54     |
# |    ent_coef_loss   | 0.0132   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 415963   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 167      |
# |    ep_rew_mean     | -1.3e+03 |
# | time/              |          |
# |    episodes        | 4978     |
# |    fps             | 58       |
# |    time_elapsed    | 142      |
# |    total_timesteps | 832030   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 167      |
# |    ep_rew_mean     | -1.3e+03 |
# | time/              |          |
# |    episodes        | 4979     |
# |    fps             | 58       |
# |    time_elapsed    | 147      |
# |    total_timesteps | 832364   |
# | train/             |          |
# |    actor_loss      | 853      |
# |    critic_loss     | 98.1     |
# |    ent_coef        | 1.53     |
# |    ent_coef_loss   | -0.0277  |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 416130   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 167      |
# |    ep_rew_mean     | -1.3e+03 |
# | time/              |          |
# |    episodes        | 4980     |
# |    fps             | 58       |
# |    time_elapsed    | 147      |
# |    total_timesteps | 832364   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 167      |
# |    ep_rew_mean     | -1.3e+03 |
# | time/              |          |
# |    episodes        | 4981     |
# |    fps             | 58       |
# |    time_elapsed    | 153      |
# |    total_timesteps | 832698   |
# | train/             |          |
# |    actor_loss      | 855      |
# |    critic_loss     | 76.2     |
# |    ent_coef        | 1.53     |
# |    ent_coef_loss   | -0.0764  |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 416297   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 167      |
# |    ep_rew_mean     | -1.3e+03 |
# | time/              |          |
# |    episodes        | 4982     |
# |    fps             | 58       |
# |    time_elapsed    | 153      |
# |    total_timesteps | 832698   |
# ---------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 167       |
# |    ep_rew_mean     | -1.29e+03 |
# | time/              |           |
# |    episodes        | 4983      |
# |    fps             | 58        |
# |    time_elapsed    | 159       |
# |    total_timesteps | 833032    |
# | train/             |           |
# |    actor_loss      | 836       |
# |    critic_loss     | 89.4      |
# |    ent_coef        | 1.51      |
# |    ent_coef_loss   | 0.029     |
# |    learning_rate   | 0.0003    |
# |    n_updates       | 416464    |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 167       |
# |    ep_rew_mean     | -1.29e+03 |
# | time/              |           |
# |    episodes        | 4984      |
# |    fps             | 58        |
# |    time_elapsed    | 159       |
# |    total_timesteps | 833032    |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 167       |
# |    ep_rew_mean     | -1.29e+03 |
# | time/              |           |
# |    episodes        | 4985      |
# |    fps             | 58        |
# |    time_elapsed    | 165       |
# |    total_timesteps | 833366    |
# | train/             |           |
# |    actor_loss      | 840       |
# |    critic_loss     | 117       |
# |    ent_coef        | 1.52      |
# |    ent_coef_loss   | -0.133    |
# |    learning_rate   | 0.0003    |
# |    n_updates       | 416631    |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 167       |
# |    ep_rew_mean     | -1.29e+03 |
# | time/              |           |
# |    episodes        | 4986      |
# |    fps             | 58        |
# |    time_elapsed    | 165       |
# |    total_timesteps | 833366    |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 167       |
# |    ep_rew_mean     | -1.29e+03 |
# | time/              |           |
# |    episodes        | 4987      |
# |    fps             | 58        |
# |    time_elapsed    | 170       |
# |    total_timesteps | 833700    |
# | train/             |           |
# |    actor_loss      | 870       |
# |    critic_loss     | 104       |
# |    ent_coef        | 1.51      |
# |    ent_coef_loss   | 0.0298    |
# |    learning_rate   | 0.0003    |
# |    n_updates       | 416798    |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 167       |
# |    ep_rew_mean     | -1.29e+03 |
# | time/              |           |
# |    episodes        | 4988      |
# |    fps             | 58        |
# |    time_elapsed    | 170       |
# |    total_timesteps | 833700    |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 167       |
# |    ep_rew_mean     | -1.29e+03 |
# | time/              |           |
# |    episodes        | 4989      |
# |    fps             | 58        |
# |    time_elapsed    | 176       |
# |    total_timesteps | 834034    |
# | train/             |           |
# |    actor_loss      | 887       |
# |    critic_loss     | 81        |
# |    ent_coef        | 1.54      |
# |    ent_coef_loss   | 0.0232    |
# |    learning_rate   | 0.0003    |
# |    n_updates       | 416965    |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 167       |
# |    ep_rew_mean     | -1.29e+03 |
# | time/              |           |
# |    episodes        | 4990      |
# |    fps             | 58        |
# |    time_elapsed    | 176       |
# |    total_timesteps | 834034    |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 167       |
# |    ep_rew_mean     | -1.28e+03 |
# | time/              |           |
# |    episodes        | 4991      |
# |    fps             | 58        |
# |    time_elapsed    | 182       |
# |    total_timesteps | 834368    |
# | train/             |           |
# |    actor_loss      | 884       |
# |    critic_loss     | 138       |
# |    ent_coef        | 1.54      |
# |    ent_coef_loss   | 0.0361    |
# |    learning_rate   | 0.0003    |
# |    n_updates       | 417132    |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 167       |
# |    ep_rew_mean     | -1.28e+03 |
# | time/              |           |
# |    episodes        | 4992      |
# |    fps             | 58        |
# |    time_elapsed    | 182       |
# |    total_timesteps | 834368    |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 167       |
# |    ep_rew_mean     | -1.28e+03 |
# | time/              |           |
# |    episodes        | 4993      |
# |    fps             | 58        |
# |    time_elapsed    | 187       |
# |    total_timesteps | 834702    |
# | train/             |           |
# |    actor_loss      | 880       |
# |    critic_loss     | 96.2      |
# |    ent_coef        | 1.53      |
# |    ent_coef_loss   | 0.012     |
# |    learning_rate   | 0.0003    |
# |    n_updates       | 417299    |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 167       |
# |    ep_rew_mean     | -1.28e+03 |
# | time/              |           |
# |    episodes        | 4994      |
# |    fps             | 58        |
# |    time_elapsed    | 187       |
# |    total_timesteps | 834702    |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 167       |
# |    ep_rew_mean     | -1.28e+03 |
# | time/              |           |
# |    episodes        | 4995      |
# |    fps             | 58        |
# |    time_elapsed    | 193       |
# |    total_timesteps | 835036    |
# | train/             |           |
# |    actor_loss      | 854       |
# |    critic_loss     | 86.4      |
# |    ent_coef        | 1.51      |
# |    ent_coef_loss   | -0.053    |
# |    learning_rate   | 0.0003    |
# |    n_updates       | 417466    |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 167       |
# |    ep_rew_mean     | -1.28e+03 |
# | time/              |           |
# |    episodes        | 4996      |
# |    fps             | 58        |
# |    time_elapsed    | 193       |
# |    total_timesteps | 835036    |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 167       |
# |    ep_rew_mean     | -1.28e+03 |
# | time/              |           |
# |    episodes        | 4997      |
# |    fps             | 58        |
# |    time_elapsed    | 198       |
# |    total_timesteps | 835370    |
# | train/             |           |
# |    actor_loss      | 853       |
# |    critic_loss     | 78.5      |
# |    ent_coef        | 1.51      |
# |    ent_coef_loss   | 0.0387    |
# |    learning_rate   | 0.0003    |
# |    n_updates       | 417633    |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 167       |
# |    ep_rew_mean     | -1.28e+03 |
# | time/              |           |
# |    episodes        | 4998      |
# |    fps             | 58        |
# |    time_elapsed    | 198       |
# |    total_timesteps | 835370    |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 167       |
# |    ep_rew_mean     | -1.27e+03 |
# | time/              |           |
# |    episodes        | 4999      |
# |    fps             | 58        |
# |    time_elapsed    | 204       |
# |    total_timesteps | 835704    |
# | train/             |           |
# |    actor_loss      | 887       |
# |    critic_loss     | 122       |
# |    ent_coef        | 1.52      |
# |    ent_coef_loss   | -0.0322   |
# |    learning_rate   | 0.0003    |
# |    n_updates       | 417800    |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 167       |
# |    ep_rew_mean     | -1.27e+03 |
# | time/              |           |
# |    episodes        | 5000      |
# |    fps             | 58        |
# |    time_elapsed    | 204       |
# |    total_timesteps | 835704    |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 167       |
# |    ep_rew_mean     | -1.28e+03 |
# | time/              |           |
# |    episodes        | 5001      |
# |    fps             | 58        |
# |    time_elapsed    | 209       |
# |    total_timesteps | 836038    |
# | train/             |           |
# |    actor_loss      | 865       |
# |    critic_loss     | 78.4      |
# |    ent_coef        | 1.53      |
# |    ent_coef_loss   | 0.0923    |
# |    learning_rate   | 0.0003    |
# |    n_updates       | 417967    |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 167       |
# |    ep_rew_mean     | -1.28e+03 |
# | time/              |           |
# |    episodes        | 5002      |
# |    fps             | 58        |
# |    time_elapsed    | 209       |
# |    total_timesteps | 836038    |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 167       |
# |    ep_rew_mean     | -1.29e+03 |
# | time/              |           |
# |    episodes        | 5003      |
# |    fps             | 58        |
# |    time_elapsed    | 215       |
# |    total_timesteps | 836372    |
# | train/             |           |
# |    actor_loss      | 833       |
# |    critic_loss     | 94.2      |
# |    ent_coef        | 1.5       |
# |    ent_coef_loss   | 0.012     |
# |    learning_rate   | 0.0003    |
# |    n_updates       | 418134    |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 167       |
# |    ep_rew_mean     | -1.29e+03 |
# | time/              |           |
# |    episodes        | 5004      |
# |    fps             | 58        |
# |    time_elapsed    | 215       |
# |    total_timesteps | 836372    |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 167       |
# |    ep_rew_mean     | -1.29e+03 |
# | time/              |           |
# |    episodes        | 5005      |
# |    fps             | 58        |
# |    time_elapsed    | 221       |
# |    total_timesteps | 836706    |
# | train/             |           |
# |    actor_loss      | 854       |
# |    critic_loss     | 93.8      |
# |    ent_coef        | 1.52      |
# |    ent_coef_loss   | 0.00103   |
# |    learning_rate   | 0.0003    |
# |    n_updates       | 418301    |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 167       |
# |    ep_rew_mean     | -1.29e+03 |
# | time/              |           |
# |    episodes        | 5006      |
# |    fps             | 58        |
# |    time_elapsed    | 221       |
# |    total_timesteps | 836706    |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 167       |
# |    ep_rew_mean     | -1.29e+03 |
# | time/              |           |
# |    episodes        | 5007      |
# |    fps             | 58        |
# |    time_elapsed    | 226       |
# |    total_timesteps | 837040    |
# | train/             |           |
# |    actor_loss      | 851       |
# |    critic_loss     | 96.8      |
# |    ent_coef        | 1.53      |
# |    ent_coef_loss   | 0.0386    |
# |    learning_rate   | 0.0003    |
# |    n_updates       | 418468    |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 167       |
# |    ep_rew_mean     | -1.29e+03 |
# | time/              |           |
# |    episodes        | 5008      |
# |    fps             | 58        |
# |    time_elapsed    | 226       |
# |    total_timesteps | 837040    |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 167       |
# |    ep_rew_mean     | -1.28e+03 |
# | time/              |           |
# |    episodes        | 5009      |
# |    fps             | 58        |
# |    time_elapsed    | 232       |
# |    total_timesteps | 837374    |
# | train/             |           |
# |    actor_loss      | 901       |
# |    critic_loss     | 102       |
# |    ent_coef        | 1.52      |
# |    ent_coef_loss   | -0.0208   |
# |    learning_rate   | 0.0003    |
# |    n_updates       | 418635    |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 167       |
# |    ep_rew_mean     | -1.28e+03 |
# | time/              |           |
# |    episodes        | 5010      |
# |    fps             | 58        |
# |    time_elapsed    | 232       |
# |    total_timesteps | 837374    |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 167       |
# |    ep_rew_mean     | -1.28e+03 |
# | time/              |           |
# |    episodes        | 5011      |
# |    fps             | 58        |
# |    time_elapsed    | 238       |
# |    total_timesteps | 837708    |
# | train/             |           |
# |    actor_loss      | 864       |
# |    critic_loss     | 91.9      |
# |    ent_coef        | 1.51      |
# |    ent_coef_loss   | 0.00118   |
# |    learning_rate   | 0.0003    |
# |    n_updates       | 418802    |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 167       |
# |    ep_rew_mean     | -1.28e+03 |
# | time/              |           |
# |    episodes        | 5012      |
# |    fps             | 58        |
# |    time_elapsed    | 238       |
# |    total_timesteps | 837708    |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 167       |
# |    ep_rew_mean     | -1.29e+03 |
# | time/              |           |
# |    episodes        | 5013      |
# |    fps             | 58        |
# |    time_elapsed    | 244       |
# |    total_timesteps | 838042    |
# | train/             |           |
# |    actor_loss      | 885       |
# |    critic_loss     | 74.5      |
# |    ent_coef        | 1.51      |
# |    ent_coef_loss   | -0.00891  |
# |    learning_rate   | 0.0003    |
# |    n_updates       | 418969    |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 167       |
# |    ep_rew_mean     | -1.29e+03 |
# | time/              |           |
# |    episodes        | 5014      |
# |    fps             | 58        |
# |    time_elapsed    | 244       |
# |    total_timesteps | 838042    |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 167       |
# |    ep_rew_mean     | -1.28e+03 |
# | time/              |           |
# |    episodes        | 5015      |
# |    fps             | 58        |
# |    time_elapsed    | 249       |
# |    total_timesteps | 838376    |
# | train/             |           |
# |    actor_loss      | 861       |
# |    critic_loss     | 109       |
# |    ent_coef        | 1.49      |
# |    ent_coef_loss   | -0.0291   |
# |    learning_rate   | 0.0003    |
# |    n_updates       | 419136    |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 167       |
# |    ep_rew_mean     | -1.28e+03 |
# | time/              |           |
# |    episodes        | 5016      |
# |    fps             | 58        |
# |    time_elapsed    | 249       |
# |    total_timesteps | 838376    |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 167       |
# |    ep_rew_mean     | -1.27e+03 |
# | time/              |           |
# |    episodes        | 5017      |
# |    fps             | 58        |
# |    time_elapsed    | 255       |
# |    total_timesteps | 838710    |
# | train/             |           |
# |    actor_loss      | 878       |
# |    critic_loss     | 89.8      |
# |    ent_coef        | 1.5       |
# |    ent_coef_loss   | 0.0159    |
# |    learning_rate   | 0.0003    |
# |    n_updates       | 419303    |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 167       |
# |    ep_rew_mean     | -1.27e+03 |
# | time/              |           |
# |    episodes        | 5018      |
# |    fps             | 58        |
# |    time_elapsed    | 255       |
# |    total_timesteps | 838710    |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 167       |
# |    ep_rew_mean     | -1.27e+03 |
# | time/              |           |
# |    episodes        | 5019      |
# |    fps             | 58        |
# |    time_elapsed    | 260       |
# |    total_timesteps | 839044    |
# | train/             |           |
# |    actor_loss      | 860       |
# |    critic_loss     | 99.7      |
# |    ent_coef        | 1.51      |
# |    ent_coef_loss   | 0.116     |
# |    learning_rate   | 0.0003    |
# |    n_updates       | 419470    |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 167       |
# |    ep_rew_mean     | -1.27e+03 |
# | time/              |           |
# |    episodes        | 5020      |
# |    fps             | 58        |
# |    time_elapsed    | 260       |
# |    total_timesteps | 839044    |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 167       |
# |    ep_rew_mean     | -1.27e+03 |
# | time/              |           |
# |    episodes        | 5021      |
# |    fps             | 59        |
# |    time_elapsed    | 265       |
# |    total_timesteps | 839378    |
# | train/             |           |
# |    actor_loss      | 848       |
# |    critic_loss     | 106       |
# |    ent_coef        | 1.5       |
# |    ent_coef_loss   | -0.0578   |
# |    learning_rate   | 0.0003    |
# |    n_updates       | 419637    |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 167       |
# |    ep_rew_mean     | -1.27e+03 |
# | time/              |           |
# |    episodes        | 5022      |
# |    fps             | 59        |
# |    time_elapsed    | 265       |
# |    total_timesteps | 839378    |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 167       |
# |    ep_rew_mean     | -1.27e+03 |
# | time/              |           |
# |    episodes        | 5023      |
# |    fps             | 59        |
# |    time_elapsed    | 271       |
# |    total_timesteps | 839712    |
# | train/             |           |
# |    actor_loss      | 839       |
# |    critic_loss     | 72.5      |
# |    ent_coef        | 1.5       |
# |    ent_coef_loss   | -0.0315   |
# |    learning_rate   | 0.0003    |
# |    n_updates       | 419804    |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 167       |
# |    ep_rew_mean     | -1.27e+03 |
# | time/              |           |
# |    episodes        | 5024      |
# |    fps             | 59        |
# |    time_elapsed    | 271       |
# |    total_timesteps | 839712    |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 167       |
# |    ep_rew_mean     | -1.26e+03 |
# | time/              |           |
# |    episodes        | 5025      |
# |    fps             | 59        |
# |    time_elapsed    | 277       |
# |    total_timesteps | 840046    |
# | train/             |           |
# |    actor_loss      | 837       |
# |    critic_loss     | 85.7      |
# |    ent_coef        | 1.5       |
# |    ent_coef_loss   | 0.0199    |
# |    learning_rate   | 0.0003    |
# |    n_updates       | 419971    |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 167       |
# |    ep_rew_mean     | -1.26e+03 |
# | time/              |           |
# |    episodes        | 5026      |
# |    fps             | 59        |
# |    time_elapsed    | 277       |
# |    total_timesteps | 840046    |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 167       |
# |    ep_rew_mean     | -1.27e+03 |
# | time/              |           |
# |    episodes        | 5027      |
# |    fps             | 59        |
# |    time_elapsed    | 282       |
# |    total_timesteps | 840380    |
# | train/             |           |
# |    actor_loss      | 834       |
# |    critic_loss     | 81.8      |
# |    ent_coef        | 1.49      |
# |    ent_coef_loss   | 0.0314    |
# |    learning_rate   | 0.0003    |
# |    n_updates       | 420138    |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 167       |
# |    ep_rew_mean     | -1.27e+03 |
# | time/              |           |
# |    episodes        | 5028      |
# |    fps             | 59        |
# |    time_elapsed    | 282       |
# |    total_timesteps | 840380    |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 167       |
# |    ep_rew_mean     | -1.27e+03 |
# | time/              |           |
# |    episodes        | 5029      |
# |    fps             | 59        |
# |    time_elapsed    | 288       |
# |    total_timesteps | 840714    |
# | train/             |           |
# |    actor_loss      | 833       |
# |    critic_loss     | 100       |
# |    ent_coef        | 1.5       |
# |    ent_coef_loss   | 0.0862    |
# |    learning_rate   | 0.0003    |
# |    n_updates       | 420305    |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 167       |
# |    ep_rew_mean     | -1.27e+03 |
# | time/              |           |
# |    episodes        | 5030      |
# |    fps             | 59        |
# ...
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 167      |
# |    ep_rew_mean     | -967     |
# | time/              |          |
# |    episodes        | 6090     |
# |    fps             | 60       |
# |    time_elapsed    | 3206     |
# |    total_timesteps | 1017734  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 167      |
# |    ep_rew_mean     | -966     |
# | time/              |          |
# |    episodes        | 6091     |
# |    fps             | 60       |
# |    time_elapsed    | 3212     |
# |    total_timesteps | 1018068  |
# | train/             |          |
# |    actor_loss      | 606      |
# |    critic_loss     | 34.1     |
# |    ent_coef        | 1.15     |
# |    ent_coef_loss   | -0.00559 |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 508982   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 167      |
# |    ep_rew_mean     | -966     |
# | time/              |          |
# |    episodes        | 6092     |
# |    fps             | 60       |
# |    time_elapsed    | 3212     |
# |    total_timesteps | 1018068  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 167      |
# |    ep_rew_mean     | -969     |
# | time/              |          |
# |    episodes        | 6093     |
# |    fps             | 60       |
# |    time_elapsed    | 3217     |
# |    total_timesteps | 1018402  |
# | train/             |          |
# |    actor_loss      | 603      |
# |    critic_loss     | 61       |
# |    ent_coef        | 1.15     |
# |    ent_coef_loss   | -0.0131  |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 509149   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 167      |
# |    ep_rew_mean     | -969     |
# | time/              |          |
# |    episodes        | 6094     |
# |    fps             | 60       |
# |    time_elapsed    | 3217     |
# |    total_timesteps | 1018402  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 167      |
# |    ep_rew_mean     | -974     |
# | time/              |          |
# |    episodes        | 6095     |
# |    fps             | 60       |
# |    time_elapsed    | 3223     |
# |    total_timesteps | 1018736  |
# | train/             |          |
# |    actor_loss      | 568      |
# |    critic_loss     | 41.1     |
# |    ent_coef        | 1.16     |
# |    ent_coef_loss   | 0.00152  |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 509316   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 167      |
# |    ep_rew_mean     | -974     |
# | time/              |          |
# |    episodes        | 6096     |
# |    fps             | 60       |
# |    time_elapsed    | 3223     |
# |    total_timesteps | 1018736  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 167      |
# |    ep_rew_mean     | -977     |
# | time/              |          |
# |    episodes        | 6097     |
# |    fps             | 60       |
# |    time_elapsed    | 3229     |
# |    total_timesteps | 1019070  |
# | train/             |          |
# |    actor_loss      | 612      |
# |    critic_loss     | 62.4     |
# |    ent_coef        | 1.16     |
# |    ent_coef_loss   | 0.0254   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 509483   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 167      |
# |    ep_rew_mean     | -977     |
# | time/              |          |
# |    episodes        | 6098     |
# |    fps             | 60       |
# |    time_elapsed    | 3229     |
# |    total_timesteps | 1019070  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 167      |
# |    ep_rew_mean     | -976     |
# | time/              |          |
# |    episodes        | 6099     |
# |    fps             | 60       |
# |    time_elapsed    | 3234     |
# |    total_timesteps | 1019404  |
# | train/             |          |
# |    actor_loss      | 585      |
# |    critic_loss     | 36.3     |
# |    ent_coef        | 1.16     |
# |    ent_coef_loss   | 0.0223   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 509650   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 167      |
# |    ep_rew_mean     | -976     |
# | time/              |          |
# |    episodes        | 6100     |
# |    fps             | 60       |
# |    time_elapsed    | 3234     |
# |    total_timesteps | 1019404  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 167      |
# |    ep_rew_mean     | -972     |
# | time/              |          |
# |    episodes        | 6101     |
# |    fps             | 60       |
# |    time_elapsed    | 3239     |
# |    total_timesteps | 1019738  |
# | train/             |          |
# |    actor_loss      | 624      |
# |    critic_loss     | 53.2     |
# |    ent_coef        | 1.14     |
# |    ent_coef_loss   | -0.0016  |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 509817   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 167      |
# |    ep_rew_mean     | -972     |
# | time/              |          |
# |    episodes        | 6102     |
# |    fps             | 60       |
# |    time_elapsed    | 3239     |
# |    total_timesteps | 1019738  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 167      |
# |    ep_rew_mean     | -969     |
# | time/              |          |
# |    episodes        | 6103     |
# |    fps             | 60       |
# |    time_elapsed    | 3245     |
# |    total_timesteps | 1020072  |
# | train/             |          |
# |    actor_loss      | 596      |
# |    critic_loss     | 45.6     |
# |    ent_coef        | 1.14     |
# |    ent_coef_loss   | 0.00351  |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 509984   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 167      |
# |    ep_rew_mean     | -969     |
# | time/              |          |
# |    episodes        | 6104     |
# |    fps             | 60       |
# |    time_elapsed    | 3245     |
# |    total_timesteps | 1020072  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 167      |
# |    ep_rew_mean     | -973     |
# | time/              |          |
# |    episodes        | 6105     |
# |    fps             | 60       |
# |    time_elapsed    | 3251     |
# |    total_timesteps | 1020406  |
# | train/             |          |
# |    actor_loss      | 616      |
# |    critic_loss     | 37.2     |
# |    ent_coef        | 1.14     |
# |    ent_coef_loss   | -0.00645 |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 510151   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 167      |
# |    ep_rew_mean     | -973     |
# | time/              |          |
# |    episodes        | 6106     |
# |    fps             | 60       |
# |    time_elapsed    | 3251     |
# |    total_timesteps | 1020406  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 167      |
# |    ep_rew_mean     | -970     |
# | time/              |          |
# |    episodes        | 6107     |
# |    fps             | 60       |
# |    time_elapsed    | 3257     |
# |    total_timesteps | 1020740  |
# | train/             |          |
# |    actor_loss      | 595      |
# |    critic_loss     | 37.5     |
# |    ent_coef        | 1.16     |
# |    ent_coef_loss   | -0.0236  |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 510318   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 167      |
# |    ep_rew_mean     | -970     |
# | time/              |          |
# |    episodes        | 6108     |
# |    fps             | 60       |
# |    time_elapsed    | 3257     |
# |    total_timesteps | 1020740  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 167      |
# |    ep_rew_mean     | -963     |
# | time/              |          |
# |    episodes        | 6109     |
# |    fps             | 60       |
# |    time_elapsed    | 3262     |
# |    total_timesteps | 1021074  |
# | train/             |          |
# |    actor_loss      | 581      |
# |    critic_loss     | 50.1     |
# |    ent_coef        | 1.14     |
# |    ent_coef_loss   | -0.00821 |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 510485   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 167      |
# |    ep_rew_mean     | -963     |
# | time/              |          |
# |    episodes        | 6110     |
# |    fps             | 60       |
# |    time_elapsed    | 3262     |
# |    total_timesteps | 1021074  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 167      |
# |    ep_rew_mean     | -956     |
# | time/              |          |
# |    episodes        | 6111     |
# |    fps             | 60       |
# |    time_elapsed    | 3267     |
# |    total_timesteps | 1021408  |
# | train/             |          |
# |    actor_loss      | 619      |
# |    critic_loss     | 54.7     |
# |    ent_coef        | 1.14     |
# |    ent_coef_loss   | -0.00652 |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 510652   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 167      |
# |    ep_rew_mean     | -956     |
# | time/              |          |
# |    episodes        | 6112     |
# |    fps             | 60       |
# |    time_elapsed    | 3267     |
# |    total_timesteps | 1021408  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 167      |
# |    ep_rew_mean     | -957     |
# | time/              |          |
# |    episodes        | 6113     |
# |    fps             | 60       |
# |    time_elapsed    | 3273     |
# |    total_timesteps | 1021742  |
# | train/             |          |
# |    actor_loss      | 602      |
# |    critic_loss     | 44.3     |
# |    ent_coef        | 1.14     |
# |    ent_coef_loss   | -0.0123  |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 510819   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 167      |
# |    ep_rew_mean     | -957     |
# | time/              |          |
# |    episodes        | 6114     |
# |    fps             | 60       |
# |    time_elapsed    | 3273     |
# |    total_timesteps | 1021742  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 167      |
# |    ep_rew_mean     | -962     |
# | time/              |          |
# |    episodes        | 6115     |
# |    fps             | 60       |
# |    time_elapsed    | 3278     |
# |    total_timesteps | 1022076  |
# | train/             |          |
# |    actor_loss      | 582      |
# |    critic_loss     | 33.7     |
# |    ent_coef        | 1.14     |
# |    ent_coef_loss   | -0.0281  |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 510986   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 167      |
# |    ep_rew_mean     | -962     |
# | time/              |          |
# |    episodes        | 6116     |
# |    fps             | 60       |
# |    time_elapsed    | 3278     |
# |    total_timesteps | 1022076  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 167      |
# |    ep_rew_mean     | -959     |
# | time/              |          |
# |    episodes        | 6117     |
# |    fps             | 60       |
# |    time_elapsed    | 3285     |
# |    total_timesteps | 1022410  |
# | train/             |          |
# |    actor_loss      | 590      |
# |    critic_loss     | 32.5     |
# |    ent_coef        | 1.14     |
# |    ent_coef_loss   | -0.00724 |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 511153   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 167      |
# |    ep_rew_mean     | -959     |
# | time/              |          |
# |    episodes        | 6118     |
# |    fps             | 60       |
# |    time_elapsed    | 3285     |
# |    total_timesteps | 1022410  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 167      |
# |    ep_rew_mean     | -962     |
# | time/              |          |
# |    episodes        | 6119     |
# |    fps             | 60       |
# |    time_elapsed    | 3291     |
# |    total_timesteps | 1022744  |
# | train/             |          |
# |    actor_loss      | 602      |
# |    critic_loss     | 45.9     |
# |    ent_coef        | 1.14     |
# |    ent_coef_loss   | -0.0121  |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 511320   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 167      |
# |    ep_rew_mean     | -962     |
# | time/              |          |
# |    episodes        | 6120     |
# |    fps             | 60       |
# |    time_elapsed    | 3291     |
# |    total_timesteps | 1022744  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 167      |
# |    ep_rew_mean     | -967     |
# | time/              |          |
# |    episodes        | 6121     |
# |    fps             | 60       |
# |    time_elapsed    | 3299     |
# |    total_timesteps | 1023078  |
# | train/             |          |
# |    actor_loss      | 590      |
# |    critic_loss     | 46.5     |
# |    ent_coef        | 1.14     |
# |    ent_coef_loss   | 0.00525  |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 511487   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 167      |
# |    ep_rew_mean     | -967     |
# | time/              |          |
# |    episodes        | 6122     |
# |    fps             | 60       |
# |    time_elapsed    | 3299     |
# |    total_timesteps | 1023078  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 167      |
# |    ep_rew_mean     | -971     |
# | time/              |          |
# |    episodes        | 6123     |
# |    fps             | 60       |
# |    time_elapsed    | 3305     |
# |    total_timesteps | 1023412  |
# | train/             |          |
# |    actor_loss      | 621      |
# |    critic_loss     | 45.3     |
# |    ent_coef        | 1.14     |
# |    ent_coef_loss   | 0.00245  |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 511654   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 167      |
# |    ep_rew_mean     | -971     |
# | time/              |          |
# |    episodes        | 6124     |
# |    fps             | 60       |
# |    time_elapsed    | 3305     |
# |    total_timesteps | 1023412  |
# ---------------------------------

# %%
# Final Save
model.save(model_dir / f"{session_name}_final")
model.save_replay_buffer(model_dir / f"{session_name}_final_replay_buffer")

# %% [markdown]
# # Evaluate (get KPIs)

# %%
# ==========================================
# 1. Configuration
# ==========================================

# Assuming the notebook is running from the same root directory as the training script
model_path = f"models/{session_name}/{session_name}_final.zip"
kpi_csv_save_path = kpi_dir / f"{session_name}.csv"

print(f"--- Evaluating {num_houses}-House Centralized SAC ---")

# ==========================================
# 2. Strict Single-Environment Initialization
# ==========================================

# Initialize without SubprocVecEnv for clean metric tracking
env = CityLearnEnv(schema_dict, central_agent=True)
env = NormalizedObservationWrapper(env)
env = StableBaselines3Wrapper(env)

# ==========================================
# 3. Model Loading & Execution
# ==========================================
if not os.path.exists(model_path):
    raise FileNotFoundError(f"Model not found at {model_path}. Verify the path.")

# SAC.load dynamically reads the architecture from the zip file,
# then the context manager intercepts the weight injection to map the keys.
with patch_module_load_state_dict():
    model = SAC.load(model_path, env=env)
# Out:
# --- Evaluating 1-House Centralized SAC ---
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.

# %%
obs, _info = env.reset()
done = False
total_reward = 0
step_count = 0

action_history = []

# %%
print("Running deterministic rollout...")

while not done:
    # extract the current state exactly as the agent sees it
    flat_obs = obs
    obs_names = env.unwrapped.observation_names[0]
    state = dict(zip(obs_names, flat_obs))

    # deterministic=True disables entropy/exploration noise, outputting the strict argmax policy
    action, _states = model.predict(obs, deterministic=True)
    action_history.append(action)

    # Safely unpack the step returns regardless of Gym/Gymnasium version
    step_returns = env.step(action)
    if len(step_returns) == 5:
        obs, reward, terminated, truncated, info = step_returns
        done = terminated or truncated
    else:
        obs, reward, done, info = step_returns

    # Handle reward unpacking based on environment wrapper behavior
    step_reward = (
        reward[0]
        if isinstance(reward, (list, tuple)) or (hasattr(reward, "shape") and len(reward.shape) > 0)
        else reward
    )
    total_reward += step_reward
    step_count += 1

# Convert lists to numpy arrays for plotting
action_history = np.array(action_history)

print(f"Rollout Complete. Total Steps: {step_count}")
print(f"Cumulative Episode Reward: {total_reward:.4f}")
# Out:
# Running deterministic rollout...
# Rollout Complete. Total Steps: 2207
# Cumulative Episode Reward: -14048.4117

# %%
# ==========================================
# 4. KPI Extraction
# ==========================================
# Extract the domain-specific metrics calculated natively by CityLearn
kpis = env.unwrapped.evaluate()
kpis = kpis.pivot(index="cost_function", columns="name", values="value").round(4)
kpis = kpis.dropna(how="all")

kpis.to_csv(kpi_csv_save_path)

print("\n=== CityLearn Key Performance Indicators ===")
display(kpis)

env.close()
# Out:
# === CityLearn Key Performance Indicators ===
# name                                           Building_1  District
# cost_function
# all_time_peak_average                                 NaN    0.8939
# annual_normalized_unserved_energy_total            0.0127    0.0127
# carbon_emissions_total                             0.7770    0.7770
# cost_total                                         0.7587    0.7587
# daily_one_minus_load_factor_average                   NaN    1.0745
# daily_peak_average                                    NaN    0.9027
# discomfort_cold_delta_average                      0.3361    0.3361
# discomfort_cold_delta_maximum                      7.2178    7.2178
# discomfort_cold_delta_minimum                      0.0000    0.0000
# discomfort_cold_proportion                         0.0290    0.0290
# discomfort_hot_delta_average                       1.0492    1.0492
# discomfort_hot_delta_maximum                       7.3245    7.3245
# discomfort_hot_delta_minimum                       0.0000    0.0000
# discomfort_hot_proportion                          0.2013    0.2013
# discomfort_proportion                              0.2302    0.2302
# electricity_consumption_total                      0.7778    0.7778
# monthly_one_minus_load_factor_average                 NaN    1.1084
# one_minus_thermal_resilience_proportion            0.8333    0.8333
# power_outage_normalized_unserved_energy_total      0.6059    0.6059
# ramping_average                                       NaN    1.1288
# zero_net_energy                                    0.7503    0.7503

# %% [markdown]
# # Investigate agent behavior

# %%
import pandas as pd
import matplotlib.dates as mdates
import matplotlib.pyplot as plt

# 1. Define time and telemetry length
T = len(action_history)

# 2. Generate hourly timestamps based on the length of the simulation
start_date = pd.Timestamp("2023-08-01 00:00:00")
timestamps = pd.date_range(start=start_date, periods=T, freq="h")

# 3. Slice telemetry to match length T
building = env.unwrapped.buildings[0]
# Use the dynamically logged telemetry instead of the baseline building object
indoor_temp = building.indoor_dry_bulb_temperature[:T]
setpoint = building.indoor_dry_bulb_temperature_cooling_set_point[:T]
soc = building.electrical_storage.soc[:T]
net_load = building.net_electricity_consumption[:T]

fig, axs = plt.subplots(3, 1, figsize=(14, 12), sharex=True)

# --- Plot 1: HVAC ---
color_temp = "tab:red"
axs[0].plot(timestamps, indoor_temp, label="Indoor Temp (°C)", color=color_temp)
axs[0].plot(timestamps, setpoint, label="Setpoint", color="darkred", linestyle="--")
axs[0].set_ylabel("Temperature (°C)", color=color_temp)

ax0_twin = axs[0].twinx()
color_act = "tab:blue"
ax0_twin.fill_between(
    timestamps, 0, action_history[:, 2], alpha=0.3, color=color_act, label="Cooling Action"
)
ax0_twin.set_ylabel("Cooling Action (0 to 1)", color=color_act)
axs[0].set_title("HVAC Diagnostics: State vs. Action")

# Combine legends
l1, lab1 = axs[0].get_legend_handles_labels()
l2, lab2 = ax0_twin.get_legend_handles_labels()
axs[0].legend(l1 + l2, lab1 + lab2, loc="upper left")

# --- Plot 2: Battery ---
color_soc = "tab:green"
axs[1].plot(timestamps, soc, label="Battery SOC", color=color_soc, linewidth=2)
axs[1].set_ylabel("State of Charge", color=color_soc)

ax1_twin = axs[1].twinx()
color_b_act = "tab:purple"
ax1_twin.step(
    timestamps, action_history[:, 1], where="post", label="Battery Action", color=color_b_act
)
ax1_twin.axhline(0, color="black", linewidth=1, linestyle="--")
ax1_twin.set_ylabel("Action (-1 to 1)", color=color_b_act)
axs[1].set_title("Battery Diagnostics: SOC vs. Action")

l1, lab1 = axs[1].get_legend_handles_labels()
l2, lab2 = ax1_twin.get_legend_handles_labels()
axs[1].legend(l1 + l2, lab1 + lab2, loc="upper left")

# --- Plot 3: Net Grid Load ---
axs[2].plot(timestamps, net_load, label="Net Grid Load (kWh)", color="black")
axs[2].axhline(0, color="gray", linewidth=1, linestyle="--")
axs[2].set_ylabel("Consumption (kWh)")
axs[2].set_title("System Outcome: Net Electricity Consumption")
axs[2].legend(loc="upper left")
axs[2].grid(True, alpha=0.4)

# 4. Format the X-Axis for Wall-Clock Time
axs[2].xaxis.set_major_formatter(mdates.DateFormatter("%b %d\n%H:%M"))
plt.xticks(rotation=0)

plt.tight_layout()

# View the first 7 days
plt.xlim(timestamps[0], timestamps[168])
plt.show()
